# %%
# %pylab
# %matplotlib inline
import pandas as pd

pylab.rcParams['figure.figsize'] = (6,4)

plt.plot([1,2,3])
# now create a subplot which represents the top plot of a grid
# with 2 rows and 1 column. Since this subplot will overlap the
# first, the plot (and its axes) previously created, will be removed
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212, axisbg='y') # creates 2nd subplot with yellow background
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
f, ax = plt.subplots(nrows=2, sharex=True, sharey=True)

s = pd.Series(np.random.randn(100) )
y = pd.Series(np.random.randn(200) * 10)
s.plot(ax=ax[0])
y.plot(ax=ax[1], style="r")

# %%
f, ax = plt.subplots(ncols=2)

df1 = pd.DataFrame({'X': np.random.randn(100), 'Y': np.random.randn(100) })
df2 = pd.DataFrame({'X': np.random.randn(100), 'Y': np.random.randn(100) })
                    
p1 = df1.plot(ax=ax[0])
p1.set_xlabel("X1")
p1.set_ylabel("Y1")
p1.set_ylim([0,10])
p2 = df2.plot(ax=ax[1])
p2.set_xlabel("X2")
p2.set_ylabel("Y2")
