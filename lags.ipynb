# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import config
from session import SessionMapper
from tama import tama, hybrid_tama
import pandas as pd


mapper = SessionMapper()

sessions = []

def load_session(session_number):
    num = str(session_number).zfill(2)
    name = "session-%s" % num
    tasks_path = "data/games-corpus/session_%s/s%s.objects.1.tasks" % (num, num)
    
    return mapper.fetch(tasks_path, name=name)

for i in range(1, 13):
    sessions.append(load_session(i))

# %% [raw]
# Let's compare them using TAMA for the first task

# %%
from helpers import cross_correlation, cross_correlogram
from operator import itemgetter

features = ["F0_MEAN", "ENG_MEAN"]

def analyze_task_feature(task, feature):
    print "Calculating %s" % feature

    A, A_mean = tama(task.speechA, feature)
    B, B_mean = tama(task.speechB, feature)

    assert np.array_equal(A.index, B.index)
    
    n = len(A)

    lag_limit = min(6, n)
    lags = range(-lag_limit, lag_limit+1)
    cross_correlations = cross_correlogram(A, B, lags)

    
    confidence_value = 2 / np.sqrt(n)
    
    # Draw all the shit
    plt.title("%s - %s" % (task.name, feature) )
    plt.xlabel("Lag")
    plt.ylabel("Correlation")
    plt.axvline(0, color="k")
    plt.axhline(0, color="k")
    cross_correlations.plot(style="bo")
    
    # Draw max points
    pos_corr = cross_correlations[cross_correlations.index >= 0]
    neg_corr = cross_correlations[cross_correlations.index <= 0]
    
    pd.Series({pos_corr.idxmax(): pos_corr.max(), neg_corr.idxmax(): neg_corr.max()}).plot(style="ro")
    
    
    
    # Draw confidence interval
    l_m, l_M = min(lags), max(lags)
    plt.hlines(confidence_value, l_m, l_M, linestyles='dashed', color='g')
    plt.hlines(-confidence_value, l_m, l_M, linestyles='dashed', color='g')


    plt.show()

    
    
for feature in features:
    print "\n" * 5
    print feature
    
    for session in sessions:
        print session.name
        for task in session.tasks:
            print "%s - %s - %s" % (feature, session.name, task.name)
            if task.length > config.TASK_LENGTH_THRESHOLD:
                analyze_task_feature(task, feature)
# Out:
# F0_MEAN
# session-01
# F0_MEAN - session-01 - Task 01
# F0_MEAN - session-01 - Task 02
# F0_MEAN - session-01 - Task 03
# F0_MEAN - session-01 - Task 04
# F0_MEAN - session-01 - Task 05
# F0_MEAN - session-01 - Task 06
# F0_MEAN - session-01 - Task 07
# F0_MEAN - session-01 - Task 08
# F0_MEAN - session-01 - Task 09
# F0_MEAN - session-01 - Task 10
# F0_MEAN - session-01 - Task 11
# F0_MEAN - session-01 - Task 12
# F0_MEAN - session-01 - Task 13
# F0_MEAN - session-01 - Task 14
# session-02
# F0_MEAN - session-02 - Task 01
# F0_MEAN - session-02 - Task 02
# F0_MEAN - session-02 - Task 03
# F0_MEAN - session-02 - Task 04
# Calculating F0_MEAN
# F0_MEAN - session-02 - Task 05
# F0_MEAN - session-02 - Task 06
# F0_MEAN - session-02 - Task 07
# F0_MEAN - session-02 - Task 08
# Calculating F0_MEAN
# F0_MEAN - session-02 - Task 09
# F0_MEAN - session-02 - Task 10
# Calculating F0_MEAN
# F0_MEAN - session-02 - Task 11
# F0_MEAN - session-02 - Task 12
# F0_MEAN - session-02 - Task 13
# Calculating F0_MEAN
# F0_MEAN - session-02 - Task 14
# session-03
# F0_MEAN - session-03 - Task 01
# Calculating F0_MEAN
# F0_MEAN - session-03 - Task 02
# F0_MEAN - session-03 - Task 03
# F0_MEAN - session-03 - Task 04
# F0_MEAN - session-03 - Task 05
# F0_MEAN - session-03 - Task 06
# F0_MEAN - session-03 - Task 07
# F0_MEAN - session-03 - Task 08
# F0_MEAN - session-03 - Task 09
# F0_MEAN - session-03 - Task 10
# Calculating F0_MEAN
# F0_MEAN - session-03 - Task 11
# F0_MEAN - session-03 - Task 12
# Calculating F0_MEAN
# F0_MEAN - session-03 - Task 13
# Calculating F0_MEAN
# F0_MEAN - session-03 - Task 14
# session-04
# F0_MEAN - session-04 - Task 01
# F0_MEAN - session-04 - Task 02
# F0_MEAN - session-04 - Task 03
# F0_MEAN - session-04 - Task 04
# F0_MEAN - session-04 - Task 05
# F0_MEAN - session-04 - Task 06
# F0_MEAN - session-04 - Task 07
# Calculating F0_MEAN
# F0_MEAN - session-04 - Task 08
# Calculating F0_MEAN
# F0_MEAN - session-04 - Task 09
# F0_MEAN - session-04 - Task 10
# Calculating F0_MEAN
# F0_MEAN - session-04 - Task 11
# F0_MEAN - session-04 - Task 12
# Calculating F0_MEAN
# F0_MEAN - session-04 - Task 13
# Calculating F0_MEAN
# F0_MEAN - session-04 - Task 14
# session-05
# F0_MEAN - session-05 - Task 01
# F0_MEAN - session-05 - Task 02
# F0_MEAN - session-05 - Task 03
# F0_MEAN - session-05 - Task 04
# F0_MEAN - session-05 - Task 05
# F0_MEAN - session-05 - Task 06
# F0_MEAN - session-05 - Task 07
# F0_MEAN - session-05 - Task 08
# F0_MEAN - session-05 - Task 09
# Calculating F0_MEAN
# F0_MEAN - session-05 - Task 10
# F0_MEAN - session-05 - Task 11
# F0_MEAN - session-05 - Task 12
# F0_MEAN - session-05 - Task 13
# Calculating F0_MEAN
# F0_MEAN - session-05 - Task 14
# Calculating F0_MEAN
# session-06
# F0_MEAN - session-06 - Task 01
# F0_MEAN - session-06 - Task 02
# F0_MEAN - session-06 - Task 03
# F0_MEAN - session-06 - Task 04
# F0_MEAN - session-06 - Task 05
# Calculating F0_MEAN
# F0_MEAN - session-06 - Task 06
# Calculating F0_MEAN
# F0_MEAN - session-06 - Task 07
# F0_MEAN - session-06 - Task 08
# Calculating F0_MEAN
# F0_MEAN - session-06 - Task 09
# F0_MEAN - session-06 - Task 10
# Calculating F0_MEAN
# F0_MEAN - session-06 - Task 11
# F0_MEAN - session-06 - Task 12
# Calculating F0_MEAN
# F0_MEAN - session-06 - Task 13
# F0_MEAN - session-06 - Task 14
# session-07
# F0_MEAN - session-07 - Task 01
# F0_MEAN - session-07 - Task 02
# F0_MEAN - session-07 - Task 03
# F0_MEAN - session-07 - Task 04
# F0_MEAN - session-07 - Task 05
# Calculating F0_MEAN
# F0_MEAN - session-07 - Task 06
# F0_MEAN - session-07 - Task 07
# F0_MEAN - session-07 - Task 08
# F0_MEAN - session-07 - Task 09
# Calculating F0_MEAN
# F0_MEAN - session-07 - Task 10
# F0_MEAN - session-07 - Task 11
# F0_MEAN - session-07 - Task 12
# F0_MEAN - session-07 - Task 13
# F0_MEAN - session-07 - Task 14
# session-08
# F0_MEAN - session-08 - Task 01
# F0_MEAN - session-08 - Task 02
# F0_MEAN - session-08 - Task 03
# F0_MEAN - session-08 - Task 04
# F0_MEAN - session-08 - Task 05
# F0_MEAN - session-08 - Task 06
# F0_MEAN - session-08 - Task 07
# F0_MEAN - session-08 - Task 08
# F0_MEAN - session-08 - Task 09
# F0_MEAN - session-08 - Task 10
# F0_MEAN - session-08 - Task 11
# F0_MEAN - session-08 - Task 12
# F0_MEAN - session-08 - Task 13
# F0_MEAN - session-08 - Task 14
# Calculating F0_MEAN
# session-09
# F0_MEAN - session-09 - Task 01
# F0_MEAN - session-09 - Task 02
# F0_MEAN - session-09 - Task 03
# F0_MEAN - session-09 - Task 04
# F0_MEAN - session-09 - Task 05
# F0_MEAN - session-09 - Task 06
# F0_MEAN - session-09 - Task 07
# F0_MEAN - session-09 - Task 08
# F0_MEAN - session-09 - Task 09
# F0_MEAN - session-09 - Task 10
# F0_MEAN - session-09 - Task 11
# F0_MEAN - session-09 - Task 12
# F0_MEAN - session-09 - Task 13
# F0_MEAN - session-09 - Task 14
# session-10
# F0_MEAN - session-10 - Task 01
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 02
# F0_MEAN - session-10 - Task 03
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 04
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 05
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 06
# F0_MEAN - session-10 - Task 07
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 08
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 09
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 10
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 11
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 12
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 13
# Calculating F0_MEAN
# F0_MEAN - session-10 - Task 14
# Calculating F0_MEAN
# session-11
# F0_MEAN - session-11 - Task 01
# F0_MEAN - session-11 - Task 02
# F0_MEAN - session-11 - Task 03
# F0_MEAN - session-11 - Task 04
# F0_MEAN - session-11 - Task 05
# F0_MEAN - session-11 - Task 06
# F0_MEAN - session-11 - Task 07
# F0_MEAN - session-11 - Task 08
# F0_MEAN - session-11 - Task 09
# F0_MEAN - session-11 - Task 10
# F0_MEAN - session-11 - Task 11
# F0_MEAN - session-11 - Task 12
# F0_MEAN - session-11 - Task 13
# F0_MEAN - session-11 - Task 14
# session-12
# F0_MEAN - session-12 - Task 01
# F0_MEAN - session-12 - Task 02
# F0_MEAN - session-12 - Task 03
# F0_MEAN - session-12 - Task 04
# F0_MEAN - session-12 - Task 05
# F0_MEAN - session-12 - Task 06
# F0_MEAN - session-12 - Task 07
# F0_MEAN - session-12 - Task 08
# F0_MEAN - session-12 - Task 09
# F0_MEAN - session-12 - Task 10
# F0_MEAN - session-12 - Task 11
# Calculating F0_MEAN
# F0_MEAN - session-12 - Task 12
# F0_MEAN - session-12 - Task 13
# F0_MEAN - session-12 - Task 14
#
#
#
#
#
#
# ENG_MEAN
# session-01
# ENG_MEAN - session-01 - Task 01
# ENG_MEAN - session-01 - Task 02
# ENG_MEAN - session-01 - Task 03
# ENG_MEAN - session-01 - Task 04
# ENG_MEAN - session-01 - Task 05
# ENG_MEAN - session-01 - Task 06
# ENG_MEAN - session-01 - Task 07
# ENG_MEAN - session-01 - Task 08
# ENG_MEAN - session-01 - Task 09
# ENG_MEAN - session-01 - Task 10
# ENG_MEAN - session-01 - Task 11
# ENG_MEAN - session-01 - Task 12
# ENG_MEAN - session-01 - Task 13
# ENG_MEAN - session-01 - Task 14
# session-02
# ENG_MEAN - session-02 - Task 01
# ENG_MEAN - session-02 - Task 02
# ENG_MEAN - session-02 - Task 03
# ENG_MEAN - session-02 - Task 04
# Calculating ENG_MEAN
# ENG_MEAN - session-02 - Task 05
# ENG_MEAN - session-02 - Task 06
# ENG_MEAN - session-02 - Task 07
# ENG_MEAN - session-02 - Task 08
# Calculating ENG_MEAN
# ENG_MEAN - session-02 - Task 09
# ENG_MEAN - session-02 - Task 10
# Calculating ENG_MEAN
# ENG_MEAN - session-02 - Task 11
# ENG_MEAN - session-02 - Task 12
# ENG_MEAN - session-02 - Task 13
# Calculating ENG_MEAN
# ENG_MEAN - session-02 - Task 14
# session-03
# ENG_MEAN - session-03 - Task 01
# Calculating ENG_MEAN
# ENG_MEAN - session-03 - Task 02
# ENG_MEAN - session-03 - Task 03
# ENG_MEAN - session-03 - Task 04
# ENG_MEAN - session-03 - Task 05
# ENG_MEAN - session-03 - Task 06
# ENG_MEAN - session-03 - Task 07
# ENG_MEAN - session-03 - Task 08
# ENG_MEAN - session-03 - Task 09
# ENG_MEAN - session-03 - Task 10
# Calculating ENG_MEAN
# ENG_MEAN - session-03 - Task 11
# ENG_MEAN - session-03 - Task 12
# Calculating ENG_MEAN
# ENG_MEAN - session-03 - Task 13
# Calculating ENG_MEAN
# ENG_MEAN - session-03 - Task 14
# session-04
# ENG_MEAN - session-04 - Task 01
# ENG_MEAN - session-04 - Task 02
# ENG_MEAN - session-04 - Task 03
# ENG_MEAN - session-04 - Task 04
# ENG_MEAN - session-04 - Task 05
# ENG_MEAN - session-04 - Task 06
# ENG_MEAN - session-04 - Task 07
# Calculating ENG_MEAN
# ENG_MEAN - session-04 - Task 08
# Calculating ENG_MEAN
# ENG_MEAN - session-04 - Task 09
# ENG_MEAN - session-04 - Task 10
# Calculating ENG_MEAN
# ENG_MEAN - session-04 - Task 11
# ENG_MEAN - session-04 - Task 12
# Calculating ENG_MEAN
# ENG_MEAN - session-04 - Task 13
# Calculating ENG_MEAN
# ENG_MEAN - session-04 - Task 14
# session-05
# ENG_MEAN - session-05 - Task 01
# ENG_MEAN - session-05 - Task 02
# ENG_MEAN - session-05 - Task 03
# ENG_MEAN - session-05 - Task 04
# ENG_MEAN - session-05 - Task 05
# ENG_MEAN - session-05 - Task 06
# ENG_MEAN - session-05 - Task 07
# ENG_MEAN - session-05 - Task 08
# ENG_MEAN - session-05 - Task 09
# Calculating ENG_MEAN
# ENG_MEAN - session-05 - Task 10
# ENG_MEAN - session-05 - Task 11
# ENG_MEAN - session-05 - Task 12
# ENG_MEAN - session-05 - Task 13
# Calculating ENG_MEAN
# ENG_MEAN - session-05 - Task 14
# Calculating ENG_MEAN
# session-06
# ENG_MEAN - session-06 - Task 01
# ENG_MEAN - session-06 - Task 02
# ENG_MEAN - session-06 - Task 03
# ENG_MEAN - session-06 - Task 04
# ENG_MEAN - session-06 - Task 05
# Calculating ENG_MEAN
# ENG_MEAN - session-06 - Task 06
# Calculating ENG_MEAN
# ENG_MEAN - session-06 - Task 07
# ENG_MEAN - session-06 - Task 08
# Calculating ENG_MEAN
# ENG_MEAN - session-06 - Task 09
# ENG_MEAN - session-06 - Task 10
# Calculating ENG_MEAN
# ENG_MEAN - session-06 - Task 11
# ENG_MEAN - session-06 - Task 12
# Calculating ENG_MEAN
# ENG_MEAN - session-06 - Task 13
# ENG_MEAN - session-06 - Task 14
# session-07
# ENG_MEAN - session-07 - Task 01
# ENG_MEAN - session-07 - Task 02
# ENG_MEAN - session-07 - Task 03
# ENG_MEAN - session-07 - Task 04
# ENG_MEAN - session-07 - Task 05
# Calculating ENG_MEAN
# ENG_MEAN - session-07 - Task 06
# ENG_MEAN - session-07 - Task 07
# ENG_MEAN - session-07 - Task 08
# ENG_MEAN - session-07 - Task 09
# Calculating ENG_MEAN
# ENG_MEAN - session-07 - Task 10
# ENG_MEAN - session-07 - Task 11
# ENG_MEAN - session-07 - Task 12
# ENG_MEAN - session-07 - Task 13
# ENG_MEAN - session-07 - Task 14
# session-08
# ENG_MEAN - session-08 - Task 01
# ENG_MEAN - session-08 - Task 02
# ENG_MEAN - session-08 - Task 03
# ENG_MEAN - session-08 - Task 04
# ENG_MEAN - session-08 - Task 05
# ENG_MEAN - session-08 - Task 06
# ENG_MEAN - session-08 - Task 07
# ENG_MEAN - session-08 - Task 08
# ENG_MEAN - session-08 - Task 09
# ENG_MEAN - session-08 - Task 10
# ENG_MEAN - session-08 - Task 11
# ENG_MEAN - session-08 - Task 12
# ENG_MEAN - session-08 - Task 13
# ENG_MEAN - session-08 - Task 14
# Calculating ENG_MEAN
# session-09
# ENG_MEAN - session-09 - Task 01
# ENG_MEAN - session-09 - Task 02
# ENG_MEAN - session-09 - Task 03
# ENG_MEAN - session-09 - Task 04
# ENG_MEAN - session-09 - Task 05
# ENG_MEAN - session-09 - Task 06
# ENG_MEAN - session-09 - Task 07
# ENG_MEAN - session-09 - Task 08
# ENG_MEAN - session-09 - Task 09
# ENG_MEAN - session-09 - Task 10
# ENG_MEAN - session-09 - Task 11
# ENG_MEAN - session-09 - Task 12
# ENG_MEAN - session-09 - Task 13
# ENG_MEAN - session-09 - Task 14
# session-10
# ENG_MEAN - session-10 - Task 01
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 02
# ENG_MEAN - session-10 - Task 03
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 04
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 05
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 06
# ENG_MEAN - session-10 - Task 07
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 08
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 09
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 10
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 11
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 12
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 13
# Calculating ENG_MEAN
# ENG_MEAN - session-10 - Task 14
# Calculating ENG_MEAN
# session-11
# ENG_MEAN - session-11 - Task 01
# ENG_MEAN - session-11 - Task 02
# ENG_MEAN - session-11 - Task 03
# ENG_MEAN - session-11 - Task 04
# ENG_MEAN - session-11 - Task 05
# ENG_MEAN - session-11 - Task 06
# ENG_MEAN - session-11 - Task 07
# ENG_MEAN - session-11 - Task 08
# ENG_MEAN - session-11 - Task 09
# ENG_MEAN - session-11 - Task 10
# ENG_MEAN - session-11 - Task 11
# ENG_MEAN - session-11 - Task 12
# ENG_MEAN - session-11 - Task 13
# ENG_MEAN - session-11 - Task 14
# session-12
# ENG_MEAN - session-12 - Task 01
# ENG_MEAN - session-12 - Task 02
# ENG_MEAN - session-12 - Task 03
# ENG_MEAN - session-12 - Task 04
# ENG_MEAN - session-12 - Task 05
# ENG_MEAN - session-12 - Task 06
# ENG_MEAN - session-12 - Task 07
# ENG_MEAN - session-12 - Task 08
# ENG_MEAN - session-12 - Task 09
# ENG_MEAN - session-12 - Task 10
# ENG_MEAN - session-12 - Task 11
# Calculating ENG_MEAN
# ENG_MEAN - session-12 - Task 12
# ENG_MEAN - session-12 - Task 13
# ENG_MEAN - session-12 - Task 14
