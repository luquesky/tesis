# %%
# %matplotlib inline

# %%
from session import SessionMapper
import config
import math
from tama import hybrid_tama
from commands.plot import plot_tamas


mapper = SessionMapper()
session = mapper.fetch("data/s10.objects.1.tasks")
# Out:
# Pickle not found. Building from scratch
# INFO:main:Pickle not found. Building from scratch

# %% [raw]
# Let's compare them using TAMA for the first task

# %%
features = ['VCD2TOT_FRAMES', 'F0_MEAN', 'F0_MAX', 'ENG_MAX', 'ENG_MEAN', 
            "NOISE_TO_HARMONICS_RATIO", "SOUND_ALL_LOCAL_JITTER", "SOUND_ALL_LOCAL_SHIMMER",
            "SOUND_VOICED_LOCAL_JITTER", "SOUND_VOICED_LOCAL_SHIMMER", "SYLLABES_COUNT", "SYLLABES_AVG",
            "PHONEMES_COUNT", "PHONEMES_AVG"
            ]

analysis = session.analyze(features)
mapper.save(session)
# Out:
# Working in task: [14.381927, 120.478197] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:iron;Score:96;Time-used:109.437
# INFO:main:Working in task: [14.381927, 120.478197] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:iron;Score:96;Time-used:109.437
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating VCD2TOT_FRAMES
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [129.9625, 193.799004] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:lime;Score:94;Time-used:88.587
# INFO:main:Working in task: [129.9625, 193.799004] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:lime;Score:94;Time-used:88.587
# Calculating VCD2TOT_FRAMES
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [222.839235, 345.111624] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:mm;Score:91;Time-used:138.520
# INFO:main:Working in task: [222.839235, 345.111624] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:mm;Score:91;Time-used:138.520
# Calculating VCD2TOT_FRAMES
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [365.699309, 495.32] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:onion;Score:99;Time-used:151.067
# INFO:main:Working in task: [365.699309, 495.32] Task: Images:yellowmermaid,mm,iron,onion,whale,bluemermaid,lime;Describer:A;Target:onion;Score:99;Time-used:151.067
# Calculating VCD2TOT_FRAMES
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [523.7399, 657.945409] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:lawnmower;Score:97;Time-used:135.665
# INFO:main:Working in task: [523.7399, 657.945409] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:lawnmower;Score:97;Time-used:135.665
# Calculating VCD2TOT_FRAMES
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [664.027045, 730.789474] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:mime;Score:95;Time-used:70.171
# INFO:main:Working in task: [664.027045, 730.789474] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:mime;Score:95;Time-used:70.171
# Calculating VCD2TOT_FRAMES
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [739.0725, 849.747197] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:owl;Score:96;Time-used:114.215
# INFO:main:Working in task: [739.0725, 849.747197] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:owl;Score:96;Time-used:114.215
# Calculating VCD2TOT_FRAMES
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [857.480192, 1014.921817] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:yellowlion;Score:99;Time-used:160.751
# INFO:main:Working in task: [857.480192, 1014.921817] Task: Images:yellowlion,ear,mime,nail,bluelion,owl,lawnmower;Describer:B;Target:yellowlion;Score:99;Time-used:160.751
# Calculating VCD2TOT_FRAMES
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [1026.993675, 1431.007297] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:A;Target:yellowmoon;Score:91;Time-used:614.429
# INFO:main:Working in task: [1026.993675, 1431.007297] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:A;Target:yellowmoon;Score:91;Time-used:614.429
# Calculating VCD2TOT_FRAMES
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [1648.6275, 2004.706632] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:B;Target:eye;Score:96;Time-used:359.247
# INFO:main:Working in task: [1648.6275, 2004.706632] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:B;Target:eye;Score:96;Time-used:359.247
# Calculating VCD2TOT_FRAMES
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# There was an error calling /home/marat/projects/tesis/scripts/voice-analysis.praat with interval [1762.721921, 1762.8275]
# ERROR:main:There was an error calling /home/marat/projects/tesis/scripts/voice-analysis.praat with interval [1762.721921, 1762.8275]
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [2010.325666, 2114.361635] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:A;Target:nun;Score:99;Time-used:108.265
# INFO:main:Working in task: [2010.325666, 2114.361635] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:A;Target:nun;Score:99;Time-used:108.265
# Calculating VCD2TOT_FRAMES
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [2122.052088, 2223.713234] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:B;Target:bluemoon;Score:96;Time-used:104.750
# INFO:main:Working in task: [2122.052088, 2223.713234] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:B;Target:bluemoon;Score:96;Time-used:104.750
# Calculating VCD2TOT_FRAMES
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [2230.080974, 2404.09] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:A;Target:mirror;Score:99;Time-used:190.354
# INFO:main:Working in task: [2230.080974, 2404.09] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:A;Target:mirror;Score:99;Time-used:190.354
# Calculating VCD2TOT_FRAMES
# There was an error calling /home/marat/projects/tesis/scripts/voice-analysis.praat with interval [2313.700322, 2314.18]
# ERROR:main:There was an error calling /home/marat/projects/tesis/scripts/voice-analysis.praat with interval [2313.700322, 2314.18]
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# ?-() has no defined phonemes. Defaulting to 0
# WARNING:main:?-() has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG
# Working in task: [2424.625988, 2533.082212] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:B;Target:ruler;Score:88;Time-used:112.873
# INFO:main:Working in task: [2424.625988, 2533.082212] Task: Images:eye,mirror,bluemoon,nun,ruler,lemon,yellowmoon;Describer:B;Target:ruler;Score:88;Time-used:112.873
# Calculating VCD2TOT_FRAMES
# uu(uu) has no defined phonemes. Defaulting to 0
# WARNING:main:uu(uu) has no defined phonemes. Defaulting to 0
# Calculating F0_MEAN
# Calculating F0_MAX
# Calculating ENG_MAX
# Calculating ENG_MEAN
# Calculating NOISE_TO_HARMONICS_RATIO
# Calculating SOUND_ALL_LOCAL_JITTER
# Calculating SOUND_ALL_LOCAL_SHIMMER
# Calculating SOUND_VOICED_LOCAL_JITTER
# Calculating SOUND_VOICED_LOCAL_SHIMMER
# Calculating SYLLABES_COUNT
# Calculating SYLLABES_AVG
# Calculating PHONEMES_COUNT
# Calculating PHONEMES_AVG

# %%
task = session.tasks[0]
feature = "F0_MEAN"

print analysis[task][feature]["cross_correlations"]
# Out:
# [(-10, 0.0), (-9, -0.013141009399480862), (-8, -0.082971807561061928), (-7, -0.21392467805505738), (-6, -0.27060447326087322), (-5, 0.17073755044422709), (-4, 0.68590330087956985), (-3, 0.31515418230585757), (-2, 0.082097529095217781), (-1, -0.15372086135604057), (0, -0.23783253627382334), (1, -0.15475434577227359), (2, -0.37028066191254055), (3, -0.28506132411821061), (4, 0.21477284666920352), (5, 0.21082322492342687), (6, 0.16626070287331601), (7, 0.010023966711657544), (8, -0.080989170631438928), (9, 0.0075075644383247493), (10, 0.0)]

# %%
from helpers import cross_correlation

display_features = features = [ 'F0_MEAN', 'F0_MAX', 'ENG_MAX', 'ENG_MEAN', "SYLLABES_COUNT", "SYLLABES_AVG",
            "PHONEMES_COUNT", "PHONEMES_AVG"
            ]

import matplotlib.pyplot as plt


for feature in display_features:
    for index, task in enumerate(session.tasks):
        task_analysis = analysis[task][feature]
        confidence_limit = task_analysis["confidence_value"]
        best_positive = task_analysis["best_positive_lag"]
        best_negative = task_analysis["best_negative_lag"]
        plt.title("Task %i - %s" % (index+1, feature) )
        plt.xlabel("Lag")
        
        plt.ylabel("Correlation")
        
        lags, ccs = zip(*task_analysis["cross_correlations"])
        plt.scatter(lags, ccs, c="b")
        l_m, l_M = min(lags), max(lags)
        plt.hlines(confidence_limit, l_m, l_M, linestyles='dashed', color='r')
        plt.hlines(-confidence_limit, l_m, l_M, linestyles='dashed', color='r')
    
        
        #plt.annotate("Best positive lag", xy=best_positive)
        plt.scatter(*zip(best_positive, best_negative), color="g", marker="D")
        
        plt.show()
