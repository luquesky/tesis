# %%
import cProfile
from tama import *
from speech import *

mapper = SpeechMapper()

# %% [raw]
# Let's calculate all without any cache

# %%
speech = SpeechBuilder("data/s10.objects.1.A.wav").speech

cProfile.run('hybrid_tama(speech, "F0_MEAN")')
# Out:
# ERROR:main:There was an error calling /home/marat/projects/tesis/scripts/voice-analysis.praat with interval [2313.700322, 2314.18]
#          30872389 function calls (29702973 primitive calls) in 173.770 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  173.770  173.770 <string>:1(<module>)
#     10209    0.009    0.000    0.031    0.000 __init__.py:1130(debug)
#         1    0.000    0.000    0.001    0.001 __init__.py:1168(error)
#         1    0.000    0.000    0.000    0.000 __init__.py:1218(findCaller)
#         1    0.000    0.000    0.000    0.000 __init__.py:1239(makeRecord)
#         1    0.000    0.000    0.001    0.001 __init__.py:1252(_log)
#         1    0.000    0.000    0.001    0.001 __init__.py:1273(handle)
#         1    0.000    0.000    0.001    0.001 __init__.py:1305(callHandlers)
#     10210    0.010    0.000    0.010    0.000 __init__.py:1331(getEffectiveLevel)
# ...

# %% [raw]
# Now, let's do it again cached

# %%
cProfile.run('hybrid_tama(speech, "F0_MEAN")')
# Out:
#          31826117 function calls (30662872 primitive calls) in 33.821 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   33.821   33.821 <string>:1(<module>)
#     10209    0.005    0.000    0.016    0.000 __init__.py:1130(debug)
#     10209    0.005    0.000    0.005    0.000 __init__.py:1331(getEffectiveLevel)
#     10209    0.006    0.000    0.011    0.000 __init__.py:1345(isEnabledFor)
# 1751531/1747795    0.486    0.000    0.499    0.000 basic.py:100(__hash__)
#      1868    0.000    0.000    0.000    0.000 basic.py:109(_hashable_content)
#      2048    0.007    0.000    0.013    0.000 basic.py:333(__eq__)
#       267    0.002    0.000    0.031    0.000 basic.py:459(__str__)
#   1165406    0.440    0.000    0.440    0.000 basic.py:642(is_comparable)
#    485986    0.129    0.000    0.129    0.000 basic.py:674(func)
# ...
