# %%
# %matplotlib inline

# %% [raw]
# Let's build the session first. This should also create the tasks...

# %%
from session import SessionMapper
import config
from tama import hybrid_tama
from commands.plot import plot_tamas, plot_autocorrelations


mapper = SessionMapper()
session = mapper.fetch("data/s10.objects.1.tasks")

# %% [raw]
# Let's compare them using TAMA for the first task

# %%
features = ['VCD2TOT_FRAMES', 'F0_MEAN', 'F0_MAX', 'ENG_MAX', 'ENG_MEAN', 
            "NOISE_TO_HARMONICS_RATIO", "SOUND_ALL_LOCAL_JITTER", "SOUND_ALL_LOCAL_SHIMMER",
            "SOUND_VOICED_LOCAL_JITTER", "SOUND_VOICED_LOCAL_SHIMMER", "SYLLABES_COUNT", "SYLLABES_AVG",
            "PHONEMES_COUNT", "PHONEMES_AVG"
            ]

tamas = session.analyze(features)
mapper.save(session)

# %%
display_features = ['F0_MEAN', 'F0_MAX', 'ENG_MAX', 'ENG_MEAN'            ]
for feature in display_features:
    for index, task in enumerate(session.tasks):
        print "Task %i" % index
        print("Tama for %s - Task %s" % (feature, index))
        TA, averagesA = tamas[task][feature]["A"]
        TB, averagesB = tamas[task][feature]["B"]
        plot_autocorrelations(feature, TA, averagesA, TB, averagesB)
# Out:
# Task 0
# Tama for F0_MEAN - Task 0
# Task 1
# Tama for F0_MEAN - Task 1
# Task 2
# Tama for F0_MEAN - Task 2
# Task 3
# Tama for F0_MEAN - Task 3
# Task 4
# Tama for F0_MEAN - Task 4
# Task 5
# Tama for F0_MEAN - Task 5
# Task 6
# Tama for F0_MEAN - Task 6
# Task 7
# Tama for F0_MEAN - Task 7
# Task 8
# Tama for F0_MEAN - Task 8
# Task 9
# Tama for F0_MEAN - Task 9
# Task 10
# Tama for F0_MEAN - Task 10
# Task 11
# Tama for F0_MEAN - Task 11
# Task 12
# Tama for F0_MEAN - Task 12
# Task 13
# Tama for F0_MEAN - Task 13
# Task 0
# Tama for F0_MAX - Task 0
# Task 1
# Tama for F0_MAX - Task 1
# Task 2
# Tama for F0_MAX - Task 2
# Task 3
# Tama for F0_MAX - Task 3
# Task 4
# Tama for F0_MAX - Task 4
# Task 5
# Tama for F0_MAX - Task 5
# Task 6
# Tama for F0_MAX - Task 6
# Task 7
# Tama for F0_MAX - Task 7
# Task 8
# Tama for F0_MAX - Task 8
# Task 9
# Tama for F0_MAX - Task 9
# Task 10
# Tama for F0_MAX - Task 10
# Task 11
# Tama for F0_MAX - Task 11
# Task 12
# Tama for F0_MAX - Task 12
# Task 13
# Tama for F0_MAX - Task 13
# Task 0
# Tama for ENG_MAX - Task 0
# Task 1
# Tama for ENG_MAX - Task 1
# Task 2
# Tama for ENG_MAX - Task 2
# Task 3
# Tama for ENG_MAX - Task 3
# Task 4
# Tama for ENG_MAX - Task 4
# Task 5
# Tama for ENG_MAX - Task 5
# Task 6
# Tama for ENG_MAX - Task 6
# Task 7
# Tama for ENG_MAX - Task 7
# Task 8
# Tama for ENG_MAX - Task 8
# Task 9
# Tama for ENG_MAX - Task 9
# Task 10
# Tama for ENG_MAX - Task 10
# Task 11
# Tama for ENG_MAX - Task 11
# Task 12
# Tama for ENG_MAX - Task 12
# Task 13
# Tama for ENG_MAX - Task 13
# Task 0
# Tama for ENG_MEAN - Task 0
# Task 1
# Tama for ENG_MEAN - Task 1
# Task 2
# Tama for ENG_MEAN - Task 2
# Task 3
# Tama for ENG_MEAN - Task 3
# Task 4
# Tama for ENG_MEAN - Task 4
# Task 5
# Tama for ENG_MEAN - Task 5
# Task 6
# Tama for ENG_MEAN - Task 6
# Task 7
# Tama for ENG_MEAN - Task 7
# Task 8
# Tama for ENG_MEAN - Task 8
# Task 9
# Tama for ENG_MEAN - Task 9
# Task 10
# Tama for ENG_MEAN - Task 10
# Task 11
# Tama for ENG_MEAN - Task 11
# Task 12
# Tama for ENG_MEAN - Task 12
# Task 13
# Tama for ENG_MEAN - Task 13
