# %% [markdown]
# # Efectos Fijos
#
# Vamos a calcular la regresión con efectos fijos sobre los datos que ya teníamos.
#
# Ver [Basic Econometrics](http://www.amazon.com/Basic-Econometrics-Damodar-Gujarati/dp/0071333452/ref=mt_paperback?_encoding=UTF8&me=)
#
#
# Primero, includes y demás configuraciones básicas

# %%
source("src/notebook_base.R")


get_regression_table <- function(data_set, explanatory_variable="entrainment") {
  # Arma una tabla con las regresiones por filas
  tabla_regresiones <- data.frame()

  for (sv in social_vars) {
    formula_reg <- as.formula(paste(paste(sv, explanatory_variable, sep = " ~ "), "", sep = "")) # Acá definimos la relación etre variable social y entr (puede ser absoluto) que va a tester la regresión
    regresion <- plm(formula_reg, data = data_set,
             model = "within",
             #effect = "individual",
             index=c("real_session", "task"))
    
    # Para que el test sea igual a STATA (http://www.richard-bluhm.com/clustered-ses-in-r-and-stata-2/)
    #G <- length(unique(data_set$real_session))
    #N <- length(data_set$real_session)
    #dfa <- (G/(G - 1)) * ((N - 1)/regresion$df.residual)
    #salida <- coeftest(regresion, vcov = dfa * vcovHC(regresion, type="HC0", cluster="group", adjust = TRUE))
    # Fuente: http://stats.stackexchange.com/questions/10017/standard-error-clustering-in-r-either-manually-or-in-plm

    salida <- coeftest(regresion, vcov=vcovHC(regresion,type="HC0",cluster="group"))
    tabla_regresiones <- rbind(tabla_regresiones, t(data.frame(as.numeric(salida))))
  }
  rownames(tabla_regresiones) <- social_vars
  colnames(tabla_regresiones) <- c("Estimate", "Std. Error", "t value", "Significance")
  return(tabla_regresiones)
}
# Out:
# Loading required package: plm
# Loading required package: Formula
# Loading required package: lmtest
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: sandwich
# Loading required package: sqldf
# Loading required package: gsubfn
# Loading required package: proto
# Loading required package: RSQLite
# Loading required package: DBI

# %% [markdown]
# ## Primer caso: $sv \sim entrainment$
#
# Vamos a armar las tablas de regresiones. En primer lugar, veamos la variable social en función del entrainment

# %%
for (ap_var in ap_vars) {
  print(ap_var)
  df <- load_csv(ap_var)
  table <- get_regression_table(df, "entrainment")
  print(xtable(table, digits=c(4,4,4,-6,4)))
}
# Out:
# [1] "ENG_MAX"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:33 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.0419 & 0.1608 & -2.606249E-01 & 0.7947 \\
#   making\_self\_clear & 0.2059 & 0.1256 & 1.639312E+00 & 0.1028 \\
#   engaged\_in\_game & 0.0824 & 0.1096 & 7.515735E-01 & 0.4533 \\
#   planning\_what\_to\_say & 0.1210 & 0.1777 & 6.809889E-01 & 0.4967 \\
#   gives\_encouragement & 0.0260 & 0.2096 & 1.242814E-01 & 0.9012 \\
#   difficult\_for\_partner\_to\_speak & -0.0521 & 0.1059 & -4.921696E-01 & 0.6232 \\
#   bored\_with\_game & 0.0403 & 0.1368 & 2.946143E-01 & 0.7686 \\
#   dislikes\_partner & -0.1238 & 0.0799 & -1.549188E+00 & 0.1230 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "ENG_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:34 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.2764 & 0.1762 & -1.568525E+00 & 0.1185 \\
#   making\_self\_clear & -0.1913 & 0.1578 & -1.212298E+00 & 0.2269 \\
#   engaged\_in\_game & 0.0461 & 0.1133 & 4.065925E-01 & 0.6848 \\
#   planning\_what\_to\_say & -0.3530 & 0.1710 & -2.063751E+00 & 0.0404 \\
#   gives\_encouragement & -0.0604 & 0.1373 & -4.395216E-01 & 0.6608 \\
#   difficult\_for\_partner\_to\_speak & -0.0236 & 0.0965 & -2.448831E-01 & 0.8068 \\
#   bored\_with\_game & 0.0450 & 0.1396 & 3.221097E-01 & 0.7477 \\
#   dislikes\_partner & -0.0795 & 0.1208 & -6.580972E-01 & 0.5113 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "F0_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:34 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.1080 & 0.1553 & 6.958097E-01 & 0.4874 \\
#   making\_self\_clear & -0.1087 & 0.1369 & -7.944581E-01 & 0.4279 \\
#   engaged\_in\_game & 0.0960 & 0.1543 & 6.224777E-01 & 0.5344 \\
#   planning\_what\_to\_say & 0.0387 & 0.1908 & 2.028172E-01 & 0.8395 \\
#   gives\_encouragement & 0.1969 & 0.2110 & 9.332302E-01 & 0.3519 \\
#   difficult\_for\_partner\_to\_speak & -0.0523 & 0.1193 & -4.385944E-01 & 0.6615 \\
#   bored\_with\_game & -0.0501 & 0.1453 & -3.448177E-01 & 0.7306 \\
#   dislikes\_partner & -0.2237 & 0.1363 & -1.641209E+00 & 0.1025 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "F0_MAX"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:35 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.1897 & 0.1613 & -1.176187E+00 & 0.2410 \\
#   making\_self\_clear & -0.4210 & 0.1420 & -2.964109E+00 & 0.0034 \\
#   engaged\_in\_game & -0.1426 & 0.0998 & -1.429872E+00 & 0.1544 \\
#   planning\_what\_to\_say & -0.2603 & 0.1880 & -1.384062E+00 & 0.1680 \\
#   gives\_encouragement & -0.1599 & 0.1723 & -9.282812E-01 & 0.3545 \\
#   difficult\_for\_partner\_to\_speak & 0.1157 & 0.1079 & 1.072261E+00 & 0.2850 \\
#   bored\_with\_game & 0.2312 & 0.1312 & 1.762576E+00 & 0.0796 \\
#   dislikes\_partner & 0.0275 & 0.0966 & 2.850641E-01 & 0.7759 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "NOISE_TO_HARMONICS_RATIO"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:35 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.0991 & 0.1287 & -7.697250E-01 & 0.4424 \\
#   making\_self\_clear & 0.0295 & 0.1147 & 2.572122E-01 & 0.7973 \\
#   engaged\_in\_game & -0.0635 & 0.1088 & -5.836380E-01 & 0.5602 \\
#   planning\_what\_to\_say & 0.0105 & 0.1697 & 6.216699E-02 & 0.9505 \\
#   gives\_encouragement & -0.0039 & 0.1662 & -2.329845E-02 & 0.9814 \\
#   difficult\_for\_partner\_to\_speak & -0.0707 & 0.1293 & -5.468867E-01 & 0.5851 \\
#   bored\_with\_game & -0.0577 & 0.1298 & -4.448072E-01 & 0.6570 \\
#   dislikes\_partner & -0.1478 & 0.1181 & -1.251802E+00 & 0.2122 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "PHONEMES_AVG"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:36 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.0531 & 0.0951 & -5.582354E-01 & 0.5774 \\
#   making\_self\_clear & -0.0193 & 0.1144 & -1.690357E-01 & 0.8660 \\
#   engaged\_in\_game & 0.0739 & 0.1052 & 7.022413E-01 & 0.4834 \\
#   planning\_what\_to\_say & 0.0719 & 0.1774 & 4.050362E-01 & 0.6859 \\
#   gives\_encouragement & -0.0976 & 0.1272 & -7.675200E-01 & 0.4438 \\
#   difficult\_for\_partner\_to\_speak & -0.0305 & 0.1258 & -2.423139E-01 & 0.8088 \\
#   bored\_with\_game & -0.0506 & 0.1048 & -4.822940E-01 & 0.6302 \\
#   dislikes\_partner & 0.0439 & 0.1242 & 3.535067E-01 & 0.7241 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SYLLABES_AVG"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:36 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.2190 & 0.0910 & -2.404832E+00 & 0.0172 \\
#   making\_self\_clear & -0.2274 & 0.1307 & -1.739940E+00 & 0.0835 \\
#   engaged\_in\_game & 0.0115 & 0.0967 & 1.184025E-01 & 0.9059 \\
#   planning\_what\_to\_say & -0.0942 & 0.1210 & -7.788229E-01 & 0.4371 \\
#   gives\_encouragement & -0.1022 & 0.1458 & -7.011635E-01 & 0.4841 \\
#   difficult\_for\_partner\_to\_speak & 0.0828 & 0.1679 & 4.932596E-01 & 0.6224 \\
#   bored\_with\_game & 0.0168 & 0.0994 & 1.686721E-01 & 0.8662 \\
#   dislikes\_partner & 0.0848 & 0.1187 & 7.144150E-01 & 0.4759 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SOUND_ALL_LOCAL_JITTER"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:37 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.0486 & 0.1648 & 2.947333E-01 & 0.7685 \\
#   making\_self\_clear & -0.0596 & 0.1784 & -3.342871E-01 & 0.7385 \\
#   engaged\_in\_game & 0.0404 & 0.1255 & 3.220789E-01 & 0.7478 \\
#   planning\_what\_to\_say & -0.2439 & 0.2088 & -1.167999E+00 & 0.2443 \\
#   gives\_encouragement & -0.2266 & 0.1293 & -1.752830E+00 & 0.0813 \\
#   difficult\_for\_partner\_to\_speak & 0.0687 & 0.1001 & 6.865220E-01 & 0.4932 \\
#   bored\_with\_game & -0.0009 & 0.1470 & -5.896917E-03 & 0.9953 \\
#   dislikes\_partner & 0.0376 & 0.1322 & 2.847338E-01 & 0.7762 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SOUND_ALL_LOCAL_SHIMMER"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:37 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.2037 & 0.1340 & -1.520119E+00 & 0.1302 \\
#   making\_self\_clear & -0.0309 & 0.1339 & -2.305465E-01 & 0.8179 \\
#   engaged\_in\_game & -0.1191 & 0.1504 & -7.918044E-01 & 0.4295 \\
#   planning\_what\_to\_say & 0.0674 & 0.1656 & 4.068042E-01 & 0.6846 \\
#   gives\_encouragement & 0.0607 & 0.1443 & 4.204239E-01 & 0.6747 \\
#   difficult\_for\_partner\_to\_speak & -0.1840 & 0.1025 & -1.796025E+00 & 0.0741 \\
#   bored\_with\_game & 0.0854 & 0.1323 & 6.456342E-01 & 0.5193 \\
#   dislikes\_partner & 0.0442 & 0.1318 & 3.357600E-01 & 0.7374 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SOUND_VOICED_LOCAL_JITTER"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:38 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.1639 & 0.1325 & -1.237284E+00 & 0.2175 \\
#   making\_self\_clear & 0.0599 & 0.1191 & 5.027404E-01 & 0.6157 \\
#   engaged\_in\_game & 0.1046 & 0.1210 & 8.647769E-01 & 0.3883 \\
#   planning\_what\_to\_say & -0.1645 & 0.1387 & -1.186003E+00 & 0.2371 \\
#   gives\_encouragement & -0.0455 & 0.1583 & -2.876258E-01 & 0.7740 \\
#   difficult\_for\_partner\_to\_speak & -0.1138 & 0.1333 & -8.538175E-01 & 0.3943 \\
#   bored\_with\_game & 0.0074 & 0.1291 & 5.720831E-02 & 0.9544 \\
#   dislikes\_partner & -0.0270 & 0.0709 & -3.802957E-01 & 0.7042 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SOUND_VOICED_LOCAL_SHIMMER"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:38 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & -0.0995 & 0.0867 & -1.147258E+00 & 0.2528 \\
#   making\_self\_clear & 0.0620 & 0.1608 & 3.855129E-01 & 0.7003 \\
#   engaged\_in\_game & -0.0521 & 0.1191 & -4.377547E-01 & 0.6621 \\
#   planning\_what\_to\_say & 0.0176 & 0.1951 & 9.011236E-02 & 0.9283 \\
#   gives\_encouragement & -0.2058 & 0.1163 & -1.770031E+00 & 0.0784 \\
#   difficult\_for\_partner\_to\_speak & -0.0420 & 0.1159 & -3.619906E-01 & 0.7178 \\
#   bored\_with\_game & 0.1097 & 0.1108 & 9.897970E-01 & 0.3236 \\
#   dislikes\_partner & -0.0158 & 0.1069 & -1.474544E-01 & 0.8829 \\
#    \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# ## Segundo caso (y más importante) $sv \sim abs(entrainment)$

# %%
tablas_regresiones <- list()
tablas_regresiones_abs <- list()

for (ap_var in ap_vars) {
  print(ap_var)
  df <- load_csv(ap_var)
  regression <- get_regression_table(df, "abs_entrainment")
  
  tablas_regresiones_abs[[ap_var]] <- regression
  # Ésto me sirve para la tabla de regresiones
  print(tablas_regresiones_abs[[ap_var]])
}
# Out:
# [1] "ENG_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.07195     0.4258  0.1690    8.660e-01
# making_self_clear                     1.69142     0.3820  4.4274    1.628e-05
# engaged_in_game                       0.34564     0.2528  1.3673    1.732e-01
# planning_what_to_say                  0.56547     0.5208  1.0859    2.790e-01
# gives_encouragement                   0.47387     0.3744  1.2655    2.073e-01
# difficult_for_partner_to_speak       -0.69250     0.2863 -2.4185    1.655e-02
# bored_with_game                       0.21104     0.2543  0.8298    4.077e-01
# dislikes_partner                     -0.42541     0.3438 -1.2373    2.175e-01
# [1] "ENG_MEAN"
#                                       Estimate Std. Error   t value
# contributes_to_successful_completion  0.655190     0.3610  1.814712
# making_self_clear                     0.946955     0.6080  1.557502
# engaged_in_game                       0.709115     0.3847  1.843187
# planning_what_to_say                  0.363629     0.5756  0.631694
# gives_encouragement                   0.405128     0.3482  1.163506
# difficult_for_partner_to_speak        0.528702     0.2515  2.101960
# bored_with_game                      -0.003558     0.4106 -0.008664
# dislikes_partner                      0.530702     0.3889  1.364514
#                                      Significance
# contributes_to_successful_completion      0.07119
# making_self_clear                         0.12106
# engaged_in_game                           0.06690
# planning_what_to_say                      0.52837
# gives_encouragement                       0.24612
# difficult_for_partner_to_speak            0.03691
# bored_with_game                           0.99310
# dislikes_partner                          0.17406
# [1] "F0_MEAN"
#                                        Estimate Std. Error   t value
# contributes_to_successful_completion  0.9751583     0.3058  3.188448
# making_self_clear                     0.6998383     0.3907  1.791239
# engaged_in_game                       0.8537722     0.2773  3.078945
# planning_what_to_say                  0.6430135     0.5363  1.198966
# gives_encouragement                   0.0006128     0.3885  0.001577
# difficult_for_partner_to_speak       -0.5323158     0.3835 -1.388190
# bored_with_game                      -0.7663276     0.2582 -2.968508
# dislikes_partner                      0.0687821     0.3808  0.180626
#                                      Significance
# contributes_to_successful_completion     0.001680
# making_self_clear                        0.074890
# engaged_in_game                          0.002394
# planning_what_to_say                     0.232075
# gives_encouragement                      0.998743
# difficult_for_partner_to_speak           0.166749
# bored_with_game                          0.003389
# dislikes_partner                         0.856858
# [1] "F0_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.76277     0.4381  1.7411      0.08332
# making_self_clear                     0.67178     0.4129  1.6270      0.10544
# engaged_in_game                       0.53079     0.3776  1.4056      0.16153
# planning_what_to_say                  0.04889     0.4210  0.1161      0.90769
# gives_encouragement                   0.47245     0.5464  0.8647      0.38832
# difficult_for_partner_to_speak       -0.32077     0.2821 -1.1369      0.25704
# bored_with_game                      -0.25842     0.3764 -0.6865      0.49326
# dislikes_partner                      0.12491     0.3884  0.3216      0.74810
# [1] "NOISE_TO_HARMONICS_RATIO"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion   0.7271     0.3439  2.1143    0.0358314
# making_self_clear                      1.3576     0.3613  3.7580    0.0002295
# engaged_in_game                        0.1270     0.3431  0.3702    0.7116537
# planning_what_to_say                  -0.1625     0.4264 -0.3812    0.7035030
# gives_encouragement                    0.7665     0.4860  1.5772    0.1164576
# difficult_for_partner_to_speak        -0.1683     0.3400 -0.4952    0.6210598
# bored_with_game                        0.5527     0.3084  1.7923    0.0747269
# dislikes_partner                       0.3457     0.3279  1.0544    0.2930704
# [1] "PHONEMES_AVG"
#                                      Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.55571     0.3577  1.55375      0.12195
# making_self_clear                     0.75978     0.5085  1.49409      0.13685
# engaged_in_game                       0.24403     0.2586  0.94384      0.34648
# planning_what_to_say                  0.36139     0.5174  0.69846      0.48576
# gives_encouragement                   0.06038     0.3829  0.15769      0.87487
# difficult_for_partner_to_speak       -0.62636     0.3374 -1.85626      0.06501
# bored_with_game                      -0.01577     0.3204 -0.04922      0.96080
# dislikes_partner                      0.09750     0.3137  0.31081      0.75630
# [1] "SYLLABES_AVG"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion   0.2451     0.3663  0.6692      0.50418
# making_self_clear                      0.7934     0.4094  1.9377      0.05418
# engaged_in_game                        0.4956     0.3642  1.3607      0.17527
# planning_what_to_say                   0.4429     0.5189  0.8535      0.39446
# gives_encouragement                    0.2363     0.4192  0.5637      0.57363
# difficult_for_partner_to_speak         0.1856     0.3481  0.5333      0.59447
# bored_with_game                       -0.2909     0.3606 -0.8068      0.42084
# dislikes_partner                       0.1768     0.3452  0.5120      0.60923
# [1] "SOUND_ALL_LOCAL_JITTER"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion   0.2778     0.3066  0.9060      0.36612
# making_self_clear                      0.7050     0.4101  1.7193      0.08723
# engaged_in_game                       -0.4003     0.4391 -0.9117      0.36314
# planning_what_to_say                  -0.5396     0.4471 -1.2067      0.22907
# gives_encouragement                   -0.1647     0.4236 -0.3888      0.69785
# difficult_for_partner_to_speak        -0.3927     0.4127 -0.9514      0.34266
# bored_with_game                        0.4519     0.5436  0.8312      0.40692
# dislikes_partner                       0.3458     0.3711  0.9316      0.35275
# [1] "SOUND_ALL_LOCAL_SHIMMER"
#                                      Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.24912     0.3483  0.71518       0.4754
# making_self_clear                     0.44031     0.4161  1.05816       0.2914
# engaged_in_game                       0.05118     0.2836  0.18046       0.8570
# planning_what_to_say                 -0.42906     0.5285 -0.81188       0.4179
# gives_encouragement                   0.03267     0.3884  0.08411       0.9331
# difficult_for_partner_to_speak        0.05177     0.4172  0.12411       0.9014
# bored_with_game                       0.31069     0.2806  1.10733       0.2696
# dislikes_partner                      0.01307     0.2474  0.05285       0.9579
# [1] "SOUND_VOICED_LOCAL_JITTER"
#                                      Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.57699     0.3759  1.53482      0.12654
# making_self_clear                     0.50574     0.4881  1.03614      0.30149
# engaged_in_game                       0.49725     0.2515  1.97713      0.04951
# planning_what_to_say                 -0.04165     0.4628 -0.09000      0.92838
# gives_encouragement                  -0.01595     0.3502 -0.04554      0.96373
# difficult_for_partner_to_speak       -0.27882     0.3126 -0.89179      0.37366
# bored_with_game                       0.12327     0.3155  0.39067      0.69649
# dislikes_partner                     -0.11705     0.2788 -0.41986      0.67508
# [1] "SOUND_VOICED_LOCAL_SHIMMER"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.374471     0.2754  1.35971      0.17558
# making_self_clear                    -0.009725     0.3821 -0.02545      0.97973
# engaged_in_game                       0.243377     0.2881  0.84491      0.39925
# planning_what_to_say                 -0.603985     0.4735 -1.27548      0.20374
# gives_encouragement                   0.363760     0.2057  1.76809      0.07869
# difficult_for_partner_to_speak        0.270690     0.2720  0.99520      0.32094
# bored_with_game                      -0.363528     0.2772 -1.31120      0.19141
# dislikes_partner                     -0.189479     0.2667 -0.71056      0.47825

# %%
# Estoy haciendo una cosa horrible. Mañana le prendo unas velitas al dios de la programación

significant <- function(r) {
    return (r["Significance"] < 0.05);
}

positive <- function(r) {
    return (r["Estimate"] > 0);
}

build_sign_table <- function() {
    signs <- data.frame(row.names=social_vars)
    
    for (ap_var in ap_vars) {
        df <- load_csv(ap_var)
        reg <- get_regression_table(df, "abs_entrainment")
            
        ap_var_col <- ifelse(significant(reg) * positive(reg), 1, 0) + ifelse(significant(reg) * (!positive(reg)) , -1, 0) 
        ap_var_col[ap_var_col == 0] <- NA
        colnames(ap_var_col) <- c(ap_var)
        
        signs[[ap_var]] <- ap_var_col
    }
  
    return(signs)
}


sign_table <- build_sign_table()

print(sign_table)
#print(xtable(sign_table, digits=0))
# Out:
#                                      ENG_MAX ENG_MEAN F0_MEAN F0_MAX
# contributes_to_successful_completion      NA       NA       1     NA
# making_self_clear                          1       NA      NA     NA
# engaged_in_game                           NA       NA       1     NA
# planning_what_to_say                      NA       NA      NA     NA
# gives_encouragement                       NA       NA      NA     NA
# difficult_for_partner_to_speak            -1        1      NA     NA
# bored_with_game                           NA       NA      -1     NA
# dislikes_partner                          NA       NA      NA     NA
#                                      NOISE_TO_HARMONICS_RATIO PHONEMES_AVG
# contributes_to_successful_completion                        1           NA
# making_self_clear                                           1           NA
# engaged_in_game                                            NA           NA
# planning_what_to_say                                       NA           NA
# gives_encouragement                                        NA           NA
# difficult_for_partner_to_speak                             NA           NA
# bored_with_game                                            NA           NA
# dislikes_partner                                           NA           NA
#                                      SYLLABES_AVG SOUND_ALL_LOCAL_JITTER
# contributes_to_successful_completion           NA                     NA
# making_self_clear                              NA                     NA
# engaged_in_game                                NA                     NA
# planning_what_to_say                           NA                     NA
# gives_encouragement                            NA                     NA
# difficult_for_partner_to_speak                 NA                     NA
# bored_with_game                                NA                     NA
# dislikes_partner                               NA                     NA
#                                      SOUND_ALL_LOCAL_SHIMMER
# contributes_to_successful_completion                      NA
# making_self_clear                                         NA
# engaged_in_game                                           NA
# planning_what_to_say                                      NA
# gives_encouragement                                       NA
# difficult_for_partner_to_speak                            NA
# bored_with_game                                           NA
# dislikes_partner                                          NA
#                                      SOUND_VOICED_LOCAL_JITTER
# contributes_to_successful_completion                        NA
# making_self_clear                                           NA
# engaged_in_game                                              1
# planning_what_to_say                                        NA
# gives_encouragement                                         NA
# difficult_for_partner_to_speak                              NA
# bored_with_game                                             NA
# dislikes_partner                                            NA
#                                      SOUND_VOICED_LOCAL_SHIMMER
# contributes_to_successful_completion                         NA
# making_self_clear                                            NA
# engaged_in_game                                              NA
# planning_what_to_say                                         NA
# gives_encouragement                                          NA
# difficult_for_partner_to_speak                               NA
# bored_with_game                                              NA
# dislikes_partner                                             NA

# %% [markdown]
# # Altamente significantes
#
# Los más significantes son
#
# 1. ENG_MAX
# 2. ENG_MEAN
# 3. F0_MEAN
# 4. NOISE_TO_HARMONICS_RATIO

# %%
for (ap_var in c("ENG_MAX", "ENG_MEAN", "F0_MEAN", "NOISE_TO_HARMONICS_RATIO")){
    df <- tablas_regresiones_abs[[ap_var]]
    print(ap_var)
    print(xtable(df, digits= c(0,4,4,4,4)))
    #print(df)
}
# Out:
# [1] "ENG_MAX"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:50 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.0720 & 0.4258 & 0.1690 & 0.8660 \\
#   making\_self\_clear & 1.6914 & 0.3820 & 4.4274 & 0.0000 \\
#   engaged\_in\_game & 0.3456 & 0.2528 & 1.3673 & 0.1732 \\
#   planning\_what\_to\_say & 0.5655 & 0.5208 & 1.0859 & 0.2790 \\
#   gives\_encouragement & 0.4739 & 0.3744 & 1.2655 & 0.2073 \\
#   difficult\_for\_partner\_to\_speak & -0.6925 & 0.2863 & -2.4185 & 0.0166 \\
#   bored\_with\_game & 0.2110 & 0.2543 & 0.8298 & 0.4077 \\
#   dislikes\_partner & -0.4254 & 0.3438 & -1.2373 & 0.2175 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "ENG_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:50 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.6552 & 0.3610 & 1.8147 & 0.0712 \\
#   making\_self\_clear & 0.9470 & 0.6080 & 1.5575 & 0.1211 \\
#   engaged\_in\_game & 0.7091 & 0.3847 & 1.8432 & 0.0669 \\
#   planning\_what\_to\_say & 0.3636 & 0.5756 & 0.6317 & 0.5284 \\
#   gives\_encouragement & 0.4051 & 0.3482 & 1.1635 & 0.2461 \\
#   difficult\_for\_partner\_to\_speak & 0.5287 & 0.2515 & 2.1020 & 0.0369 \\
#   bored\_with\_game & -0.0036 & 0.4106 & -0.0087 & 0.9931 \\
#   dislikes\_partner & 0.5307 & 0.3889 & 1.3645 & 0.1741 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "F0_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:50 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.9752 & 0.3058 & 3.1884 & 0.0017 \\
#   making\_self\_clear & 0.6998 & 0.3907 & 1.7912 & 0.0749 \\
#   engaged\_in\_game & 0.8538 & 0.2773 & 3.0789 & 0.0024 \\
#   planning\_what\_to\_say & 0.6430 & 0.5363 & 1.1990 & 0.2321 \\
#   gives\_encouragement & 0.0006 & 0.3885 & 0.0016 & 0.9987 \\
#   difficult\_for\_partner\_to\_speak & -0.5323 & 0.3835 & -1.3882 & 0.1667 \\
#   bored\_with\_game & -0.7663 & 0.2582 & -2.9685 & 0.0034 \\
#   dislikes\_partner & 0.0688 & 0.3808 & 0.1806 & 0.8569 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "NOISE_TO_HARMONICS_RATIO"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sat Mar  5 21:15:50 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.7271 & 0.3439 & 2.1143 & 0.0358 \\
#   making\_self\_clear & 1.3576 & 0.3613 & 3.7580 & 0.0002 \\
#   engaged\_in\_game & 0.1270 & 0.3431 & 0.3702 & 0.7117 \\
#   planning\_what\_to\_say & -0.1625 & 0.4264 & -0.3812 & 0.7035 \\
#   gives\_encouragement & 0.7665 & 0.4860 & 1.5772 & 0.1165 \\
#   difficult\_for\_partner\_to\_speak & -0.1683 & 0.3400 & -0.4952 & 0.6211 \\
#   bored\_with\_game & 0.5527 & 0.3084 & 1.7923 & 0.0747 \\
#   dislikes\_partner & 0.3457 & 0.3279 & 1.0544 & 0.2931 \\
#    \hline
# \end{tabular}
# \end{table}
