# %% [markdown]
# # Efectos Fijos
#
# Vamos a calcular la regresión con efectos fijos sobre los datos que ya teníamos.
#
# Ver [Basic Econometrics](http://www.amazon.com/Basic-Econometrics-Damodar-Gujarati/dp/0071333452/ref=mt_paperback?_encoding=UTF8&me=)
#
#
# Primero, includes y demás configuraciones básicas

# %%
source("src/notebook_base.R")


get_regression_table <- function(data_set, explanatory_variable="entrainment") {
  # Arma una tabla con las regresiones por filas
  tabla_regresiones <- data.frame()

  for (sv in social_vars) {
    formula_reg <- as.formula(paste(paste(sv, explanatory_variable, sep = " ~ "), "", sep = "")) # Acá definimos la relación etre variable social y entr (puede ser absoluto) que va a tester la regresión
    regresion <- plm(formula_reg, data = data_set,
             model = "within",
             #effect = "individual",
             index=c("real_session", "task"))
    
    # Para que el test sea igual a STATA (http://www.richard-bluhm.com/clustered-ses-in-r-and-stata-2/)
    #G <- length(unique(data_set$real_session))
    #N <- length(data_set$real_session)
    #dfa <- (G/(G - 1)) * ((N - 1)/regresion$df.residual)
    #salida <- coeftest(regresion, vcov = dfa * vcovHC(regresion, type="HC0", cluster="group", adjust = TRUE))
    # Fuente: http://stats.stackexchange.com/questions/10017/standard-error-clustering-in-r-either-manually-or-in-plm

    salida <- coeftest(regresion, vcov=vcovHC(regresion,type="HC0",cluster="group"))
    tabla_regresiones <- rbind(tabla_regresiones, t(data.frame(as.numeric(salida))))
  }
  rownames(tabla_regresiones) <- social_vars
  colnames(tabla_regresiones) <- c("Estimate", "Std. Error", "t value", "Significance")
  return(tabla_regresiones)
}
# Out:
# Loading required package: plm
# Loading required package: Formula
# Loading required package: lmtest
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: sandwich
# Loading required package: sqldf
# Loading required package: gsubfn
# Loading required package: proto
# Loading required package: RSQLite
# Loading required package: DBI

# %% [markdown]
# ## Primer caso: $sv \sim entrainment$
#
# Vamos a armar las tablas de regresiones. En primer lugar, veamos la variable social en función del entrainment

# %%
for (ap_var in ap_vars) {
  print(ap_var)
  df <- load_csv(ap_var)
  print(get_regression_table(df, "entrainment"))
}
# Out:
# [1] "ENG_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.08375    0.15450 -0.5421      0.58843
# making_self_clear                     0.23214    0.12531  1.8525      0.06555
# engaged_in_game                       0.02925    0.08437  0.3466      0.72927
# planning_what_to_say                  0.08509    0.15460  0.5504      0.58271
# gives_encouragement                   0.06846    0.20469  0.3344      0.73843
# difficult_for_partner_to_speak       -0.11129    0.11771 -0.9454      0.34566
# bored_with_game                       0.04776    0.11831  0.4037      0.68690
# dislikes_partner                     -0.07072    0.08402 -0.8417      0.40105
# [1] "ENG_MEAN"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.26591     0.1738 -1.5301       0.1277
# making_self_clear                    -0.15143     0.1495 -1.0130       0.3124
# engaged_in_game                       0.04031     0.1250  0.3225       0.7475
# planning_what_to_say                 -0.17346     0.1846 -0.9398       0.3485
# gives_encouragement                  -0.04261     0.1322 -0.3223       0.7476
# difficult_for_partner_to_speak        0.01106     0.1100  0.1006       0.9200
# bored_with_game                       0.02167     0.1436  0.1510       0.8802
# dislikes_partner                     -0.02813     0.1235 -0.2277       0.8201
# [1] "F0_MEAN"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.111699     0.1474  0.75767      0.44961
# making_self_clear                    -0.079606     0.1342 -0.59321      0.55377
# engaged_in_game                       0.088999     0.1363  0.65308      0.51451
# planning_what_to_say                  0.094290     0.1807  0.52178      0.60245
# gives_encouragement                   0.122461     0.1793  0.68284      0.49556
# difficult_for_partner_to_speak       -0.005968     0.1257 -0.04749      0.96218
# bored_with_game                       0.027682     0.1213  0.22820      0.81974
# dislikes_partner                     -0.211219     0.1110 -1.90350      0.05853
# [1] "F0_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.10208    0.13236 -0.7712       0.4416
# making_self_clear                    -0.16782    0.12484 -1.3443       0.1805
# engaged_in_game                       0.02262    0.09644  0.2345       0.8148
# planning_what_to_say                 -0.17296    0.12880 -1.3428       0.1810
# gives_encouragement                   0.01798    0.14838  0.1212       0.9037
# difficult_for_partner_to_speak        0.06821    0.09333  0.7309       0.4658
# bored_with_game                       0.13644    0.11402  1.1967       0.2330
# dislikes_partner                     -0.05805    0.08789 -0.6605       0.5098
# [1] "NOISE_TO_HARMONICS_RATIO"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.06365     0.1346 -0.4730      0.63676
# making_self_clear                     0.03065     0.1066  0.2876      0.77396
# engaged_in_game                      -0.08412     0.1017 -0.8272      0.40921
# planning_what_to_say                  0.07257     0.1471  0.4932      0.62246
# gives_encouragement                  -0.06952     0.1681 -0.4136      0.67963
# difficult_for_partner_to_speak       -0.05022     0.1033 -0.4862      0.62739
# bored_with_game                      -0.03224     0.1245 -0.2589      0.79598
# dislikes_partner                     -0.27761     0.1212 -2.2901      0.02314
# [1] "PHONEMES_AVG"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.06223    0.09018 -0.6901       0.4910
# making_self_clear                     0.09432    0.10845  0.8697       0.3856
# engaged_in_game                       0.03643    0.07355  0.4953       0.6210
# planning_what_to_say                  0.02649    0.17838  0.1485       0.8821
# gives_encouragement                  -0.01153    0.11110 -0.1038       0.9174
# difficult_for_partner_to_speak       -0.08350    0.12776 -0.6536       0.5142
# bored_with_game                      -0.02621    0.08671 -0.3022       0.7628
# dislikes_partner                     -0.12017    0.08715 -1.3790       0.1696
# [1] "PHONEMES_COUNT"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion -0.159082    0.15808 -1.00633       0.3156
# making_self_clear                     0.132366    0.13825  0.95741       0.3396
# engaged_in_game                       0.012476    0.13422  0.09295       0.9260
# planning_what_to_say                  0.028352    0.17962  0.15784       0.8748
# gives_encouragement                  -0.001917    0.14161 -0.01354       0.9892
# difficult_for_partner_to_speak       -0.127218    0.13865 -0.91755       0.3600
# bored_with_game                      -0.100848    0.14574 -0.69196       0.4898
# dislikes_partner                      0.060152    0.09095  0.66134       0.5092
# [1] "SOUND_VOICED_LOCAL_SHIMMER"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion -0.120911     0.1021 -1.18465       0.2377
# making_self_clear                     0.025391     0.1339  0.18959       0.8498
# engaged_in_game                      -0.145909     0.1141 -1.27924       0.2024
# planning_what_to_say                 -0.021144     0.1926 -0.10978       0.9127
# gives_encouragement                  -0.099124     0.1365 -0.72634       0.4685
# difficult_for_partner_to_speak       -0.007488     0.1194 -0.06269       0.9501
# bored_with_game                       0.130458     0.1157  1.12731       0.2611
# dislikes_partner                     -0.017168     0.1171 -0.14659       0.8836
# [1] "SYLLABES_AVG"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion -0.130683    0.10635 -1.22878       0.2207
# making_self_clear                     0.005322    0.12305  0.04326       0.9655
# engaged_in_game                       0.041637    0.08843  0.47087       0.6383
# planning_what_to_say                  0.107118    0.12155  0.88129       0.3793
# gives_encouragement                  -0.023502    0.12948 -0.18151       0.8562
# difficult_for_partner_to_speak       -0.048635    0.14150 -0.34371       0.7315
# bored_with_game                       0.038360    0.11052  0.34709       0.7289
# dislikes_partner                     -0.034059    0.10563 -0.32245       0.7475
# [1] "SYLLABES_COUNT"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion -0.068055     0.1493 -0.45583       0.6490
# making_self_clear                     0.136166     0.1336  1.01900       0.3095
# engaged_in_game                      -0.038795     0.1459 -0.26582       0.7907
# planning_what_to_say                 -0.108132     0.1961 -0.55132       0.5821
# gives_encouragement                   0.042650     0.1231  0.34634       0.7295
# difficult_for_partner_to_speak        0.004542     0.1600  0.02839       0.9774
# bored_with_game                      -0.046646     0.1608 -0.29008       0.7721
# dislikes_partner                      0.040156     0.1025  0.39177       0.6957
# [1] "VCD2TOT_FRAMES"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.07364    0.15598 -0.4721      0.63741
# making_self_clear                    -0.26374    0.14314 -1.8426      0.06699
# engaged_in_game                      -0.05113    0.14252 -0.3587      0.72021
# planning_what_to_say                  0.19315    0.20060  0.9628      0.33689
# gives_encouragement                  -0.20656    0.17779 -1.1618      0.24680
# difficult_for_partner_to_speak        0.03824    0.12052  0.3173      0.75135
# bored_with_game                       0.10342    0.11747  0.8804      0.37977
# dislikes_partner                     -0.02394    0.09455 -0.2532      0.80038

# %% [markdown]
# ## Segundo caso (y más importante) $sv \sim abs(entrainment)$

# %%
tablas_regresiones <- list()
tablas_regresiones_abs <- list()

for (ap_var in ap_vars) {
  print(ap_var)
  df <- load_csv(ap_var)
  regression <- get_regression_table(df, "abs_entrainment")
  
  tablas_regresiones_abs[[ap_var]] <- regression
  # Ésto me sirve para la tabla de regresiones
  print(tablas_regresiones_abs[[ap_var]])
}
# Out:
# [1] "ENG_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.07697     0.4197  0.1834    0.8546870
# making_self_clear                     1.39914     0.3971  3.5232    0.0005371
# engaged_in_game                       0.16702     0.2492  0.6702    0.5035367
# planning_what_to_say                  0.21340     0.4609  0.4630    0.6439243
# gives_encouragement                   0.51606     0.3330  1.5496    0.1229378
# difficult_for_partner_to_speak       -0.56032     0.2822 -1.9858    0.0485345
# bored_with_game                       0.34943     0.2488  1.4043    0.1618930
# dislikes_partner                     -0.53267     0.3658 -1.4560    0.1470749
# [1] "ENG_MEAN"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.721912     0.3643  1.98162      0.04900
# making_self_clear                     0.815517     0.5061  1.61136      0.10881
# engaged_in_game                       0.654793     0.3739  1.75125      0.08156
# planning_what_to_say                  0.608194     0.5589  1.08812      0.27796
# gives_encouragement                   0.322888     0.3212  1.00525      0.31609
# difficult_for_partner_to_speak        0.360281     0.2968  1.21396      0.22631
# bored_with_game                      -0.002264     0.4036 -0.00561      0.99553
# dislikes_partner                      0.313666     0.3569  0.87876      0.38067
# [1] "F0_MEAN"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.99752     0.3545  2.8142     0.005419
# making_self_clear                     0.63363     0.3126  2.0269     0.044108
# engaged_in_game                       0.67184     0.3337  2.0135     0.045511
# planning_what_to_say                  0.73933     0.4760  1.5533     0.122067
# gives_encouragement                   0.07390     0.3981  0.1856     0.852947
# difficult_for_partner_to_speak       -0.55826     0.4012 -1.3916     0.165723
# bored_with_game                      -0.40238     0.3038 -1.3244     0.186992
# dislikes_partner                     -0.03183     0.3437 -0.0926     0.926318
# [1] "F0_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  1.01729     0.4767  2.1340      0.03416
# making_self_clear                     0.68729     0.4141  1.6596      0.09868
# engaged_in_game                       0.53911     0.3775  1.4282      0.15492
# planning_what_to_say                  0.26933     0.4297  0.6268      0.53158
# gives_encouragement                   0.41168     0.4743  0.8680      0.38651
# difficult_for_partner_to_speak       -0.09113     0.3213 -0.2836      0.77703
# bored_with_game                      -0.31484     0.3606 -0.8731      0.38371
# dislikes_partner                      0.30550     0.3434  0.8897      0.37480
# [1] "NOISE_TO_HARMONICS_RATIO"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.53215     0.3217  1.6543      0.09977
# making_self_clear                     0.82640     0.3677  2.2477      0.02578
# engaged_in_game                       0.34377     0.3111  1.1052      0.27051
# planning_what_to_say                 -0.12444     0.3979 -0.3127      0.75485
# gives_encouragement                   0.37753     0.4017  0.9398      0.34853
# difficult_for_partner_to_speak        0.06904     0.2383  0.2897      0.77234
# bored_with_game                       0.30642     0.2670  1.1475      0.25266
# dislikes_partner                      0.18884     0.3405  0.5546      0.57985
# [1] "PHONEMES_AVG"
#                                      Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.36264     0.3681  0.98525      0.32579
# making_self_clear                     0.77992     0.4652  1.67663      0.09530
# engaged_in_game                       0.23164     0.2722  0.85104      0.39585
# planning_what_to_say                  0.73732     0.5703  1.29294      0.19764
# gives_encouragement                  -0.01477     0.3278 -0.04505      0.96411
# difficult_for_partner_to_speak       -0.75239     0.3554 -2.11704      0.03559
# bored_with_game                       0.02318     0.2833  0.08182      0.93488
# dislikes_partner                      0.04779     0.2749  0.17385      0.86218
# [1] "PHONEMES_COUNT"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.13876     0.3507  0.3957      0.69281
# making_self_clear                     0.36148     0.3306  1.0936      0.27557
# engaged_in_game                       0.16192     0.4294  0.3771      0.70657
# planning_what_to_say                  0.39573     0.4020  0.9844      0.32619
# gives_encouragement                  -0.69704     0.2803 -2.4870      0.01377
# difficult_for_partner_to_speak       -0.35711     0.4535 -0.7875      0.43197
# bored_with_game                       0.06298     0.4157  0.1515      0.87976
# dislikes_partner                     -0.30068     0.3486 -0.8626      0.38950
# [1] "SOUND_VOICED_LOCAL_SHIMMER"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion   0.2969     0.3373  0.8802       0.3799
# making_self_clear                      0.1051     0.3587  0.2931       0.7698
# engaged_in_game                        0.1084     0.2732  0.3969       0.6919
# planning_what_to_say                  -0.7106     0.4780 -1.4865       0.1388
# gives_encouragement                    0.2282     0.2084  1.0949       0.2750
# difficult_for_partner_to_speak         0.1375     0.2891  0.4755       0.6350
# bored_with_game                       -0.1864     0.2063 -0.9039       0.3672
# dislikes_partner                      -0.1071     0.3094 -0.3463       0.7295
# [1] "SYLLABES_AVG"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.17135     0.3724  0.4601       0.6460
# making_self_clear                     0.77171     0.3599  2.1444       0.0333
# engaged_in_game                       0.34793     0.3449  1.0087       0.3145
# planning_what_to_say                  0.62548     0.4297  1.4557       0.1472
# gives_encouragement                   0.53536     0.3314  1.6155       0.1079
# difficult_for_partner_to_speak        0.18658     0.3403  0.5483       0.5842
# bored_with_game                      -0.12424     0.3463 -0.3588       0.7202
# dislikes_partner                      0.07938     0.2817  0.2818       0.7784
# [1] "SYLLABES_COUNT"
#                                      Estimate Std. Error  t value Significance
# contributes_to_successful_completion  0.20940     0.3969  0.52760      0.59841
# making_self_clear                     0.70716     0.3768  1.87681      0.06212
# engaged_in_game                       0.35033     0.4674  0.74957      0.45447
# planning_what_to_say                  0.58571     0.3367  1.73980      0.08356
# gives_encouragement                  -0.64165     0.3365 -1.90656      0.05813
# difficult_for_partner_to_speak       -0.42193     0.4652 -0.90696      0.36561
# bored_with_game                       0.01609     0.4765  0.03377      0.97310
# dislikes_partner                     -0.29903     0.3440 -0.86929      0.38582
# [1] "VCD2TOT_FRAMES"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.16176     0.3110  0.5201       0.6036
# making_self_clear                    -0.51364     0.3737 -1.3746       0.1709
# engaged_in_game                       0.20182     0.2561  0.7881       0.4317
# planning_what_to_say                  0.36567     0.5241  0.6977       0.4863
# gives_encouragement                   0.50118     0.3094  1.6201       0.1069
# difficult_for_partner_to_speak        0.09431     0.3438  0.2743       0.7842
# bored_with_game                       0.06373     0.4584  0.1390       0.8896
# dislikes_partner                     -0.35422     0.3585 -0.9882       0.3244

# %%
# Estoy haciendo una cosa horrible. Mañana le prendo unas velitas al dios de la programación

significant <- function(r) {
    return (r["Significance"] < 0.05);
}

positive <- function(r) {
    return (r["Estimate"] > 0);
}

build_sign_table <- function() {
    signs <- data.frame(row.names=social_vars)
    
    for (ap_var in ap_vars) {
        df <- load_csv(ap_var)
        reg <- get_regression_table(df, "abs_entrainment")
            
        ap_var_col <- ifelse(significant(reg) * positive(reg), 1, 0) + ifelse(significant(reg) * (!positive(reg)) , -1, 0) 
        ap_var_col[ap_var_col == 0] <- NA
        colnames(ap_var_col) <- c(ap_var)
        
        signs[[ap_var]] <- ap_var_col
    }
  
    return(signs)
}


sign_table <- build_sign_table()

print(sign_table)
#print(xtable(sign_table, digits=0))
# Out:
#                                      ENG_MAX ENG_MEAN F0_MEAN F0_MAX
# contributes_to_successful_completion      NA        1       1      1
# making_self_clear                          1       NA       1     NA
# engaged_in_game                           NA       NA       1     NA
# planning_what_to_say                      NA       NA      NA     NA
# gives_encouragement                       NA       NA      NA     NA
# difficult_for_partner_to_speak            -1       NA      NA     NA
# bored_with_game                           NA       NA      NA     NA
# dislikes_partner                          NA       NA      NA     NA
#                                      NOISE_TO_HARMONICS_RATIO PHONEMES_AVG
# contributes_to_successful_completion                       NA           NA
# making_self_clear                                           1           NA
# engaged_in_game                                            NA           NA
# planning_what_to_say                                       NA           NA
# gives_encouragement                                        NA           NA
# difficult_for_partner_to_speak                             NA           -1
# bored_with_game                                            NA           NA
# dislikes_partner                                           NA           NA
#                                      PHONEMES_COUNT SOUND_VOICED_LOCAL_SHIMMER
# contributes_to_successful_completion             NA                         NA
# making_self_clear                                NA                         NA
# engaged_in_game                                  NA                         NA
# planning_what_to_say                             NA                         NA
# gives_encouragement                              -1                         NA
# difficult_for_partner_to_speak                   NA                         NA
# bored_with_game                                  NA                         NA
# dislikes_partner                                 NA                         NA
#                                      SYLLABES_AVG SYLLABES_COUNT VCD2TOT_FRAMES
# contributes_to_successful_completion           NA             NA             NA
# making_self_clear                               1             NA             NA
# engaged_in_game                                NA             NA             NA
# planning_what_to_say                           NA             NA             NA
# gives_encouragement                            NA             NA             NA
# difficult_for_partner_to_speak                 NA             NA             NA
# bored_with_game                                NA             NA             NA
# dislikes_partner                               NA             NA             NA

# %% [markdown]
# # Altamente significantes
#
# Los más significantes son
#
# 1. ENG_MAX
# 2. ENG_MEAN
# 3. F0_MEAN
# 4. NOISE_TO_HARMONICS_RATIO

# %%
for (ap_var in c("ENG_MAX", "ENG_MEAN", "F0_MEAN", "NOISE_TO_HARMONICS_RATIO")){
    df <- tablas_regresiones_abs[[ap_var]]
    print(ap_var)
    print(xtable(df, digits= c(0,4,4,4,4)))
    #print(df)
}
# Out:
# [1] "ENG_MAX"
# % latex table generated in R 3.2.3 by xtable 1.8-0 package
# % Mon Feb 22 12:44:28 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.0770 & 0.4197 & 0.1834 & 0.8547 \\
#   making\_self\_clear & 1.3991 & 0.3971 & 3.5232 & 0.0005 \\
#   engaged\_in\_game & 0.1670 & 0.2492 & 0.6702 & 0.5035 \\
#   planning\_what\_to\_say & 0.2134 & 0.4609 & 0.4630 & 0.6439 \\
#   gives\_encouragement & 0.5161 & 0.3330 & 1.5496 & 0.1229 \\
#   difficult\_for\_partner\_to\_speak & -0.5603 & 0.2822 & -1.9858 & 0.0485 \\
#   bored\_with\_game & 0.3494 & 0.2488 & 1.4043 & 0.1619 \\
#   dislikes\_partner & -0.5327 & 0.3658 & -1.4560 & 0.1471 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "ENG_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-0 package
# % Mon Feb 22 12:44:28 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.7219 & 0.3643 & 1.9816 & 0.0490 \\
#   making\_self\_clear & 0.8155 & 0.5061 & 1.6114 & 0.1088 \\
#   engaged\_in\_game & 0.6548 & 0.3739 & 1.7512 & 0.0816 \\
#   planning\_what\_to\_say & 0.6082 & 0.5589 & 1.0881 & 0.2780 \\
#   gives\_encouragement & 0.3229 & 0.3212 & 1.0052 & 0.3161 \\
#   difficult\_for\_partner\_to\_speak & 0.3603 & 0.2968 & 1.2140 & 0.2263 \\
#   bored\_with\_game & -0.0023 & 0.4036 & -0.0056 & 0.9955 \\
#   dislikes\_partner & 0.3137 & 0.3569 & 0.8788 & 0.3807 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "F0_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-0 package
# % Mon Feb 22 12:44:28 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.9975 & 0.3545 & 2.8142 & 0.0054 \\
#   making\_self\_clear & 0.6336 & 0.3126 & 2.0269 & 0.0441 \\
#   engaged\_in\_game & 0.6718 & 0.3337 & 2.0135 & 0.0455 \\
#   planning\_what\_to\_say & 0.7393 & 0.4760 & 1.5533 & 0.1221 \\
#   gives\_encouragement & 0.0739 & 0.3981 & 0.1856 & 0.8529 \\
#   difficult\_for\_partner\_to\_speak & -0.5583 & 0.4012 & -1.3916 & 0.1657 \\
#   bored\_with\_game & -0.4024 & 0.3038 & -1.3244 & 0.1870 \\
#   dislikes\_partner & -0.0318 & 0.3437 & -0.0926 & 0.9263 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "NOISE_TO_HARMONICS_RATIO"
# % latex table generated in R 3.2.3 by xtable 1.8-0 package
# % Mon Feb 22 12:44:28 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.5322 & 0.3217 & 1.6543 & 0.0998 \\
#   making\_self\_clear & 0.8264 & 0.3677 & 2.2477 & 0.0258 \\
#   engaged\_in\_game & 0.3438 & 0.3111 & 1.1052 & 0.2705 \\
#   planning\_what\_to\_say & -0.1244 & 0.3979 & -0.3127 & 0.7548 \\
#   gives\_encouragement & 0.3775 & 0.4017 & 0.9398 & 0.3485 \\
#   difficult\_for\_partner\_to\_speak & 0.0690 & 0.2383 & 0.2897 & 0.7723 \\
#   bored\_with\_game & 0.3064 & 0.2670 & 1.1475 & 0.2527 \\
#   dislikes\_partner & 0.1888 & 0.3405 & 0.5546 & 0.5799 \\
#    \hline
# \end{tabular}
# \end{table}
