# %% [markdown]
# # Efectos Fijos
#
# Vamos a calcular la regresión con efectos fijos sobre los datos que ya teníamos.
#
# Ver [Basic Econometrics](http://www.amazon.com/Basic-Econometrics-Damodar-Gujarati/dp/0071333452/ref=mt_paperback?_encoding=UTF8&me=)
#
#
# Primero, includes y demás configuraciones básicas

# %%
source("src/notebook_base.R")


get_regression_table <- function(data_set, explanatory_variable="entrainment") {
  # Arma una tabla con las regresiones por filas
  tabla_regresiones <- data.frame()

  for (sv in social_vars) {
    formula_reg <- as.formula(paste(paste(sv, explanatory_variable, sep = " ~ "), "", sep = "")) # Acá definimos la relación etre variable social y entr (puede ser absoluto) que va a tester la regresión
    regresion <- plm(formula_reg, data = data_set,
             model = "within",
             #effect = "individual",
             index=c("real_session", "task"))
    
    # Para que el test sea igual a STATA (http://www.richard-bluhm.com/clustered-ses-in-r-and-stata-2/)
    #G <- length(unique(data_set$real_session))
    #N <- length(data_set$real_session)
    #dfa <- (G/(G - 1)) * ((N - 1)/regresion$df.residual)
    #salida <- coeftest(regresion, vcov = dfa * vcovHC(regresion, type="HC0", cluster="group", adjust = TRUE))
    # Fuente: http://stats.stackexchange.com/questions/10017/standard-error-clustering-in-r-either-manually-or-in-plm

    salida <- coeftest(regresion, vcov=vcovHC(regresion,type="HC0",cluster="group"))
    tabla_regresiones <- rbind(tabla_regresiones, t(data.frame(as.numeric(salida))))
  }
  rownames(tabla_regresiones) <- social_vars
  colnames(tabla_regresiones) <- c("Estimate", "Std. Error", "t value", "Significance")
  return(tabla_regresiones)
}
# Out:
# Loading required package: plm
# Loading required package: Formula
# Loading required package: lmtest
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: sandwich
# Loading required package: sqldf
# Loading required package: gsubfn
# Loading required package: proto
# Loading required package: RSQLite
# Loading required package: DBI

# %% [markdown]
# ## Primer caso: $sv \sim entrainment$
#
# Vamos a armar las tablas de regresiones. En primer lugar, veamos la variable social en función del entrainment

# %%
for (ap_var in ap_vars) {
  print(ap_var)
  df <- load_csv(ap_var)
  table <- get_regression_table(df, "entrainment")
  print(table, digits=c(4,4,4,4))
  #print(xtable(table, digits=c(4,4,4,-6,4)))
}
# Out:
# [1] "ENG_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.04191    0.16081 -0.2606       0.7947
# making_self_clear                     0.20587    0.12558  1.6393       0.1028
# engaged_in_game                       0.08240    0.10963  0.7516       0.4533
# planning_what_to_say                  0.12102    0.17771  0.6810       0.4967
# gives_encouragement                   0.02604    0.20956  0.1243       0.9012
# difficult_for_partner_to_speak       -0.05213    0.10592 -0.4922       0.6232
# bored_with_game                       0.04031    0.13681  0.2946       0.7686
# dislikes_partner                     -0.12385    0.07994 -1.5492       0.1230
# [1] "ENG_MEAN"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.27645    0.17625 -1.5685      0.11847
# making_self_clear                    -0.19134    0.15783 -1.2123      0.22694
# engaged_in_game                       0.04606    0.11328  0.4066      0.68478
# planning_what_to_say                 -0.35300    0.17105 -2.0638      0.04044
# gives_encouragement                  -0.06037    0.13735 -0.4395      0.66080
# difficult_for_partner_to_speak       -0.02364    0.09653 -0.2449      0.80682
# bored_with_game                       0.04498    0.13963  0.3221      0.74773
# dislikes_partner                     -0.07947    0.12076 -0.6581      0.51129
# [1] "F0_MEAN"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion  0.10805     0.1553  0.6958       0.4874
# making_self_clear                    -0.10873     0.1369 -0.7945       0.4279
# engaged_in_game                       0.09605     0.1543  0.6225       0.5344
# planning_what_to_say                  0.03870     0.1908  0.2028       0.8395
# gives_encouragement                   0.19693     0.2110  0.9332       0.3519
# difficult_for_partner_to_speak       -0.05231     0.1193 -0.4386       0.6615
# bored_with_game                      -0.05011     0.1453 -0.3448       0.7306
# dislikes_partner                     -0.22366     0.1363 -1.6412       0.1025
# [1] "F0_MAX"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.18973    0.16131 -1.1762     0.241032
# making_self_clear                    -0.42097    0.14202 -2.9641     0.003435
# engaged_in_game                      -0.14265    0.09976 -1.4299     0.154440
# planning_what_to_say                 -0.26027    0.18804 -1.3841     0.168007
# gives_encouragement                  -0.15993    0.17228 -0.9283     0.354471
# difficult_for_partner_to_speak        0.11573    0.10793  1.0723     0.284999
# bored_with_game                       0.23121    0.13118  1.7626     0.079623
# dislikes_partner                      0.02753    0.09659  0.2851     0.775914
# [1] "NOISE_TO_HARMONICS_RATIO"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion -0.099100     0.1287 -0.76972       0.4424
# making_self_clear                     0.029501     0.1147  0.25721       0.7973
# engaged_in_game                      -0.063488     0.1088 -0.58364       0.5602
# planning_what_to_say                  0.010549     0.1697  0.06217       0.9505
# gives_encouragement                  -0.003873     0.1662 -0.02330       0.9814
# difficult_for_partner_to_speak       -0.070726     0.1293 -0.54689       0.5851
# bored_with_game                      -0.057739     0.1298 -0.44481       0.6570
# dislikes_partner                     -0.147783     0.1181 -1.25180       0.2122
# [1] "PHONEMES_AVG"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.05306    0.09505 -0.5582       0.5774
# making_self_clear                    -0.01934    0.11439 -0.1690       0.8660
# engaged_in_game                       0.07386    0.10518  0.7022       0.4834
# planning_what_to_say                  0.07185    0.17740  0.4050       0.6859
# gives_encouragement                  -0.09764    0.12722 -0.7675       0.4438
# difficult_for_partner_to_speak       -0.03048    0.12578 -0.2423       0.8088
# bored_with_game                      -0.05057    0.10485 -0.4823       0.6302
# dislikes_partner                      0.04392    0.12423  0.3535       0.7241
# [1] "SYLLABES_AVG"
#                                      Estimate Std. Error t value Significance
# contributes_to_successful_completion -0.21896    0.09105 -2.4048      0.01717
# making_self_clear                    -0.22738    0.13068 -1.7399      0.08353
# engaged_in_game                       0.01145    0.09674  0.1184      0.90588
# planning_what_to_say                 -0.09421    0.12096 -0.7788      0.43708
# gives_encouragement                  -0.10225    0.14583 -0.7012      0.48408
# difficult_for_partner_to_speak        0.08284    0.16795  0.4933      0.62241
# bored_with_game                       0.01676    0.09939  0.1687      0.86624
# dislikes_partner                      0.08480    0.11870  0.7144      0.47587
# [1] "SOUND_VOICED_LOCAL_JITTER"
#                                       Estimate Std. Error  t value Significance
# contributes_to_successful_completion -0.163928    0.13249 -1.23728       0.2175
# making_self_clear                     0.059896    0.11914  0.50274       0.6157
# engaged_in_game                       0.104615    0.12097  0.86478       0.3883
# planning_what_to_say                 -0.164457    0.13866 -1.18600       0.2371
# gives_encouragement                  -0.045531    0.15830 -0.28763       0.7740
# difficult_for_partner_to_speak       -0.113780    0.13326 -0.85382       0.3943
# bored_with_game                       0.007383    0.12905  0.05721       0.9544
# dislikes_partner                     -0.026955    0.07088 -0.38030       0.7042
# [1] "SOUND_VOICED_LOCAL_SHIMMER"
#                                      Estimate Std. Error  t value Significance
# contributes_to_successful_completion -0.09948    0.08671 -1.14726      0.25276
# making_self_clear                     0.06198    0.16078  0.38551      0.70030
# engaged_in_game                      -0.05212    0.11906 -0.43775      0.66207
# planning_what_to_say                  0.01758    0.19512  0.09011      0.92830
# gives_encouragement                  -0.20579    0.11626 -1.77003      0.07837
# difficult_for_partner_to_speak       -0.04196    0.11592 -0.36199      0.71777
# bored_with_game                       0.10966    0.11079  0.98980      0.32357
# dislikes_partner                     -0.01576    0.10690 -0.14745      0.88293

# %% [markdown]
# ## Segundo caso (y más importante) $sv \sim abs(entrainment)$

# %%
tablas_regresiones <- list()
tablas_regresiones_abs <- list()

for (ap_var in ap_vars) {
  print(ap_var)
  df <- load_csv(ap_var)
  table <- get_regression_table(df, "abs_entrainment")
  
  tablas_regresiones_abs[[ap_var]] <- table
  # Ésto me sirve para la tabla de regresiones
  print(xtable(table, digits=c(4,4,4,-6,4)))
  #print(table, digits=4)
}
# Out:
# [1] "ENG_MAX"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:35 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.0720 & 0.4258 & 1.689631E-01 & 0.8660 \\
#   making\_self\_clear & 1.6914 & 0.3820 & 4.427376E+00 & 0.0000 \\
#   engaged\_in\_game & 0.3456 & 0.2528 & 1.367266E+00 & 0.1732 \\
#   planning\_what\_to\_say & 0.5655 & 0.5208 & 1.085851E+00 & 0.2790 \\
#   gives\_encouragement & 0.4739 & 0.3744 & 1.265523E+00 & 0.2073 \\
#   difficult\_for\_partner\_to\_speak & -0.6925 & 0.2863 & -2.418510E+00 & 0.0166 \\
#   bored\_with\_game & 0.2110 & 0.2543 & 8.298495E-01 & 0.4077 \\
#   dislikes\_partner & -0.4254 & 0.3438 & -1.237312E+00 & 0.2175 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "ENG_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:36 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.6552 & 0.3610 & 1.814712E+00 & 0.0712 \\
#   making\_self\_clear & 0.9470 & 0.6080 & 1.557502E+00 & 0.1211 \\
#   engaged\_in\_game & 0.7091 & 0.3847 & 1.843187E+00 & 0.0669 \\
#   planning\_what\_to\_say & 0.3636 & 0.5756 & 6.316937E-01 & 0.5284 \\
#   gives\_encouragement & 0.4051 & 0.3482 & 1.163506E+00 & 0.2461 \\
#   difficult\_for\_partner\_to\_speak & 0.5287 & 0.2515 & 2.101960E+00 & 0.0369 \\
#   bored\_with\_game & -0.0036 & 0.4106 & -8.663987E-03 & 0.9931 \\
#   dislikes\_partner & 0.5307 & 0.3889 & 1.364514E+00 & 0.1741 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "F0_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:36 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.9752 & 0.3058 & 3.188448E+00 & 0.0017 \\
#   making\_self\_clear & 0.6998 & 0.3907 & 1.791239E+00 & 0.0749 \\
#   engaged\_in\_game & 0.8538 & 0.2773 & 3.078945E+00 & 0.0024 \\
#   planning\_what\_to\_say & 0.6430 & 0.5363 & 1.198966E+00 & 0.2321 \\
#   gives\_encouragement & 0.0006 & 0.3885 & 1.577445E-03 & 0.9987 \\
#   difficult\_for\_partner\_to\_speak & -0.5323 & 0.3835 & -1.388190E+00 & 0.1667 \\
#   bored\_with\_game & -0.7663 & 0.2582 & -2.968508E+00 & 0.0034 \\
#   dislikes\_partner & 0.0688 & 0.3808 & 1.806265E-01 & 0.8569 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "F0_MAX"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:37 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.7628 & 0.4381 & 1.741129E+00 & 0.0833 \\
#   making\_self\_clear & 0.6718 & 0.4129 & 1.626984E+00 & 0.1054 \\
#   engaged\_in\_game & 0.5308 & 0.3776 & 1.405582E+00 & 0.1615 \\
#   planning\_what\_to\_say & 0.0489 & 0.4210 & 1.161167E-01 & 0.9077 \\
#   gives\_encouragement & 0.4724 & 0.5464 & 8.647145E-01 & 0.3883 \\
#   difficult\_for\_partner\_to\_speak & -0.3208 & 0.2821 & -1.136927E+00 & 0.2570 \\
#   bored\_with\_game & -0.2584 & 0.3764 & -6.865032E-01 & 0.4933 \\
#   dislikes\_partner & 0.1249 & 0.3884 & 3.216226E-01 & 0.7481 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "NOISE_TO_HARMONICS_RATIO"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:37 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.7271 & 0.3439 & 2.114275E+00 & 0.0358 \\
#   making\_self\_clear & 1.3576 & 0.3613 & 3.758007E+00 & 0.0002 \\
#   engaged\_in\_game & 0.1270 & 0.3431 & 3.702043E-01 & 0.7117 \\
#   planning\_what\_to\_say & -0.1625 & 0.4264 & -3.811856E-01 & 0.7035 \\
#   gives\_encouragement & 0.7665 & 0.4860 & 1.577201E+00 & 0.1165 \\
#   difficult\_for\_partner\_to\_speak & -0.1683 & 0.3400 & -4.951813E-01 & 0.6211 \\
#   bored\_with\_game & 0.5527 & 0.3084 & 1.792251E+00 & 0.0747 \\
#   dislikes\_partner & 0.3457 & 0.3279 & 1.054410E+00 & 0.2931 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "PHONEMES_AVG"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:38 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.5557 & 0.3577 & 1.553747E+00 & 0.1220 \\
#   making\_self\_clear & 0.7598 & 0.5085 & 1.494093E+00 & 0.1369 \\
#   engaged\_in\_game & 0.2440 & 0.2586 & 9.438356E-01 & 0.3465 \\
#   planning\_what\_to\_say & 0.3614 & 0.5174 & 6.984626E-01 & 0.4858 \\
#   gives\_encouragement & 0.0604 & 0.3829 & 1.576928E-01 & 0.8749 \\
#   difficult\_for\_partner\_to\_speak & -0.6264 & 0.3374 & -1.856257E+00 & 0.0650 \\
#   bored\_with\_game & -0.0158 & 0.3204 & -4.921947E-02 & 0.9608 \\
#   dislikes\_partner & 0.0975 & 0.3137 & 3.108070E-01 & 0.7563 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SYLLABES_AVG"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:38 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.2451 & 0.3663 & 6.692398E-01 & 0.5042 \\
#   making\_self\_clear & 0.7934 & 0.4094 & 1.937743E+00 & 0.0542 \\
#   engaged\_in\_game & 0.4956 & 0.3642 & 1.360687E+00 & 0.1753 \\
#   planning\_what\_to\_say & 0.4429 & 0.5189 & 8.535430E-01 & 0.3945 \\
#   gives\_encouragement & 0.2363 & 0.4192 & 5.637211E-01 & 0.5736 \\
#   difficult\_for\_partner\_to\_speak & 0.1856 & 0.3481 & 5.332959E-01 & 0.5945 \\
#   bored\_with\_game & -0.2909 & 0.3606 & -8.067536E-01 & 0.4208 \\
#   dislikes\_partner & 0.1768 & 0.3452 & 5.120454E-01 & 0.6092 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SOUND_VOICED_LOCAL_JITTER"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:39 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.5770 & 0.3759 & 1.534821E+00 & 0.1265 \\
#   making\_self\_clear & 0.5057 & 0.4881 & 1.036143E+00 & 0.3015 \\
#   engaged\_in\_game & 0.4972 & 0.2515 & 1.977130E+00 & 0.0495 \\
#   planning\_what\_to\_say & -0.0417 & 0.4628 & -9.000210E-02 & 0.9284 \\
#   gives\_encouragement & -0.0160 & 0.3502 & -4.554031E-02 & 0.9637 \\
#   difficult\_for\_partner\_to\_speak & -0.2788 & 0.3126 & -8.917922E-01 & 0.3737 \\
#   bored\_with\_game & 0.1233 & 0.3155 & 3.906725E-01 & 0.6965 \\
#   dislikes\_partner & -0.1171 & 0.2788 & -4.198582E-01 & 0.6751 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "SOUND_VOICED_LOCAL_SHIMMER"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:22:40 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.3745 & 0.2754 & 1.359709E+00 & 0.1756 \\
#   making\_self\_clear & -0.0097 & 0.3821 & -2.544762E-02 & 0.9797 \\
#   engaged\_in\_game & 0.2434 & 0.2881 & 8.449092E-01 & 0.3993 \\
#   planning\_what\_to\_say & -0.6040 & 0.4735 & -1.275476E+00 & 0.2037 \\
#   gives\_encouragement & 0.3638 & 0.2057 & 1.768094E+00 & 0.0787 \\
#   difficult\_for\_partner\_to\_speak & 0.2707 & 0.2720 & 9.952034E-01 & 0.3209 \\
#   bored\_with\_game & -0.3635 & 0.2772 & -1.311203E+00 & 0.1914 \\
#   dislikes\_partner & -0.1895 & 0.2667 & -7.105564E-01 & 0.4783 \\
#    \hline
# \end{tabular}
# \end{table}

# %%
# Estoy haciendo una cosa horrible. Mañana le prendo unas velitas al dios de la programación

significant <- function(r) {
    return (r["Significance"] < 0.05);
}

positive <- function(r) {
    return (r["Estimate"] > 0);
}

build_sign_table <- function() {
    signs <- data.frame(row.names=social_vars)
    
    for (ap_var in ap_vars) {
        df <- load_csv(ap_var)
        reg <- get_regression_table(df, "abs_entrainment")
            
        ap_var_col <- ifelse(significant(reg) * positive(reg), 1, 0) + ifelse(significant(reg) * (!positive(reg)) , -1, 0) 
        ap_var_col[ap_var_col == 0] <- NA
        colnames(ap_var_col) <- c(ap_var)
        
        signs[[ap_var]] <- ap_var_col
    }
  
    return(signs)
}


sign_table <- build_sign_table()

print(sign_table)
#print(xtable(sign_table, digits=0))
# Out:
#                                      ENG_MAX ENG_MEAN F0_MEAN F0_MAX
# contributes_to_successful_completion      NA       NA       1     NA
# making_self_clear                          1       NA      NA     NA
# engaged_in_game                           NA       NA       1     NA
# planning_what_to_say                      NA       NA      NA     NA
# gives_encouragement                       NA       NA      NA     NA
# difficult_for_partner_to_speak            -1        1      NA     NA
# bored_with_game                           NA       NA      -1     NA
# dislikes_partner                          NA       NA      NA     NA
#                                      NOISE_TO_HARMONICS_RATIO PHONEMES_AVG
# contributes_to_successful_completion                        1           NA
# making_self_clear                                           1           NA
# engaged_in_game                                            NA           NA
# planning_what_to_say                                       NA           NA
# gives_encouragement                                        NA           NA
# difficult_for_partner_to_speak                             NA           NA
# bored_with_game                                            NA           NA
# dislikes_partner                                           NA           NA
#                                      SYLLABES_AVG SOUND_VOICED_LOCAL_JITTER
# contributes_to_successful_completion           NA                        NA
# making_self_clear                              NA                        NA
# engaged_in_game                                NA                         1
# planning_what_to_say                           NA                        NA
# gives_encouragement                            NA                        NA
# difficult_for_partner_to_speak                 NA                        NA
# bored_with_game                                NA                        NA
# dislikes_partner                               NA                        NA
#                                      SOUND_VOICED_LOCAL_SHIMMER
# contributes_to_successful_completion                         NA
# making_self_clear                                            NA
# engaged_in_game                                              NA
# planning_what_to_say                                         NA
# gives_encouragement                                          NA
# difficult_for_partner_to_speak                               NA
# bored_with_game                                              NA
# dislikes_partner                                             NA

# %% [markdown]
# # Altamente significantes
#
# Los más significantes son
#
# 1. ENG_MAX
# 2. ENG_MEAN
# 3. F0_MEAN
# 4. NOISE_TO_HARMONICS_RATIO

# %%
for (ap_var in c("ENG_MAX", "ENG_MEAN", "F0_MEAN", "NOISE_TO_HARMONICS_RATIO")){
    df <- tablas_regresiones_abs[[ap_var]]
    print(ap_var)
    print(xtable(df, digits= c(0,4,4,4,4)))
    #print(df)
}
# Out:
# [1] "ENG_MAX"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:18:14 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.0720 & 0.4258 & 0.1690 & 0.8660 \\
#   making\_self\_clear & 1.6914 & 0.3820 & 4.4274 & 0.0000 \\
#   engaged\_in\_game & 0.3456 & 0.2528 & 1.3673 & 0.1732 \\
#   planning\_what\_to\_say & 0.5655 & 0.5208 & 1.0859 & 0.2790 \\
#   gives\_encouragement & 0.4739 & 0.3744 & 1.2655 & 0.2073 \\
#   difficult\_for\_partner\_to\_speak & -0.6925 & 0.2863 & -2.4185 & 0.0166 \\
#   bored\_with\_game & 0.2110 & 0.2543 & 0.8298 & 0.4077 \\
#   dislikes\_partner & -0.4254 & 0.3438 & -1.2373 & 0.2175 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "ENG_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:18:14 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.6552 & 0.3610 & 1.8147 & 0.0712 \\
#   making\_self\_clear & 0.9470 & 0.6080 & 1.5575 & 0.1211 \\
#   engaged\_in\_game & 0.7091 & 0.3847 & 1.8432 & 0.0669 \\
#   planning\_what\_to\_say & 0.3636 & 0.5756 & 0.6317 & 0.5284 \\
#   gives\_encouragement & 0.4051 & 0.3482 & 1.1635 & 0.2461 \\
#   difficult\_for\_partner\_to\_speak & 0.5287 & 0.2515 & 2.1020 & 0.0369 \\
#   bored\_with\_game & -0.0036 & 0.4106 & -0.0087 & 0.9931 \\
#   dislikes\_partner & 0.5307 & 0.3889 & 1.3645 & 0.1741 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "F0_MEAN"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:18:14 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.9752 & 0.3058 & 3.1884 & 0.0017 \\
#   making\_self\_clear & 0.6998 & 0.3907 & 1.7912 & 0.0749 \\
#   engaged\_in\_game & 0.8538 & 0.2773 & 3.0789 & 0.0024 \\
#   planning\_what\_to\_say & 0.6430 & 0.5363 & 1.1990 & 0.2321 \\
#   gives\_encouragement & 0.0006 & 0.3885 & 0.0016 & 0.9987 \\
#   difficult\_for\_partner\_to\_speak & -0.5323 & 0.3835 & -1.3882 & 0.1667 \\
#   bored\_with\_game & -0.7663 & 0.2582 & -2.9685 & 0.0034 \\
#   dislikes\_partner & 0.0688 & 0.3808 & 0.1806 & 0.8569 \\
#    \hline
# \end{tabular}
# \end{table}
# [1] "NOISE_TO_HARMONICS_RATIO"
# % latex table generated in R 3.2.3 by xtable 1.8-2 package
# % Sun Mar  6 13:18:14 2016
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrrr}
#   \hline
#  & Estimate & Std. Error & t value & Significance \\
#   \hline
# contributes\_to\_successful\_completion & 0.7271 & 0.3439 & 2.1143 & 0.0358 \\
#   making\_self\_clear & 1.3576 & 0.3613 & 3.7580 & 0.0002 \\
#   engaged\_in\_game & 0.1270 & 0.3431 & 0.3702 & 0.7117 \\
#   planning\_what\_to\_say & -0.1625 & 0.4264 & -0.3812 & 0.7035 \\
#   gives\_encouragement & 0.7665 & 0.4860 & 1.5772 & 0.1165 \\
#   difficult\_for\_partner\_to\_speak & -0.1683 & 0.3400 & -0.4952 & 0.6211 \\
#   bored\_with\_game & 0.5527 & 0.3084 & 1.7923 & 0.0747 \\
#   dislikes\_partner & 0.3457 & 0.3279 & 1.0544 & 0.2931 \\
#    \hline
# \end{tabular}
# \end{table}
