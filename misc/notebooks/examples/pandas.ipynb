# %%
# %matplotlib inline
import os
os.chdir("../..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [raw]
# Create a series

# %%
s = pd.Series(100* np.random.randn(300))
s.plot()

s.cumsum().plot()
#s.cumsum().cumsum().plot()

# %% [raw]
# Series with missing data

# %%
def g(n):
    for i in range(n):
        n = np.random.rand()
        n = n if n < 0.9 else np.nan
        yield n

pd.Series(g(100)).plot()

# %% [raw]
# Calculate correlations with missing values

# %%
X = pd.Series([1,2,np.nan, 4, 5])
Y = pd.Series([1,np.nan, 3, 4, 5])

X.corr(Y)
# Out:
# 1.0

# %%
X = pd.Series([1,2,3,4,5], index=range(5,10))
Y = pd.Series([1,2,3,4,5])

X.corr(Y)
# Out:
# nan

# %%
X.index
# Out:
# Int64Index([5, 6, 7, 8, 9], dtype='int64')

# %%
pd.Series(np.random.randn(100)).plot(style="o-")

# %%
X = pd.Series(np.random.randn(20))
Y = pd.Series(np.random.randn(20))

X_norm = (X - X.mean()) / X.std()
Y_norm = (Y - Y.mean()) / Y.std()

# %%
X.plot(style='o-')
Y.plot(style='o-')

# %% [markdown]
# ## DataFrames:
#
# (Robado de la documentación) "Two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). Arithmetic operations align on both row and column labels. Can be thought of as a dict-like container for Series objects. The primary pandas data structure"

# %%
D = pd.DataFrame({'a': np.random.randn(20), 'b': np.random.randn(20)})

D
# Out:
#            a         b
# 0  -1.013802 -2.140418
# 1   0.449808 -0.409012
# 2  -0.484860  0.340321
# 3   1.942436 -1.505797
# 4  -1.001316 -0.173722
# 5   1.622344 -1.501429
# 6  -0.179996  1.160840
# 7  -0.720376  0.529018
# 8   0.575278 -0.196472
# 9  -0.541941 -0.991149
# 10 -1.331140 -0.385286
# 11  0.633046 -0.218464
# 12 -0.204922 -0.634482
# 13 -0.249070  0.153049
# 14  0.261547 -0.235858
# 15 -0.728792  0.806315
# 16 -0.702782  0.653184
# 17 -1.828933 -1.400396
# 18 -0.053127  0.417907
# 19  1.114797  0.096164

# %%
D.plot(color=['r', 'r'])

# %% [raw]
# Armemos dos series y veamos cómo queda el data frame

# %%
X = pd.Series([0,1,2], index=[0,1,2])
Y = pd.Series([1,2,3], index=[1,2,3])
Z = pd.Series([2,3,4], index=[2,3,4])

d = { 'X': X, 'Y': Y, 'Z': Z}

# %% [markdown]
# Vamos a armar un DataFrame de un diccionario. El Data Frame resultante va a tener como columnas a las claves del diccionario, y como filas el índice resultante de la unión de los índices de cada serie (en este caso `[0,1,2,3]`)
#
# Los datos faltantes se rellenan con `np.nan`

# %%
pd.DataFrame(d)
# Out:
#     X   Y   Z
# 0   0 NaN NaN
# 1   1   1 NaN
# 2   2   2   2
# 3 NaN   3   3
# 4 NaN NaN   4

# %% [markdown]
# Me quedo sólo con un par de columnas e índices

# %%
pd.DataFrame(d, columns=['X', 'Y'], index=[1,2])
# Out:
#    X  Y
# 1  1  1
# 2  2  2

# %%
pd.DataFrame(d).plot()

# %%
# %pylab
# %matplotlib inline
import pandas as pd

pylab.rcParams['figure.figsize'] = (12,4)

f, ax = plt.subplots(ncols=2)

D.plot(ax=ax[0])
D.plot(ax=ax[1], color=['r', 'y'])
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Veamos de graficar un dataframe y la media de sus columnas

# %%
D = pd.DataFrame({'a': np.random.randn(20), 'b': np.random.randn(20), 'c': np.random.randn(20) })

D.plot(style="o-")
D.mean(axis=1).plot(style="ro-", linewidth=5.0)

# %%
df1 = pd.DataFrame({'X': np.random.randn(10), 'Y': np.random.randn(10) })
df2 = pd.DataFrame({'X': np.random.randn(10), 'Y': np.random.randn(10) })

df = pd.DataFrame({'1': df1, '2': df2})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-249e88529261> in <module>()
#       2 df2 = pd.DataFrame({'X': np.random.randn(10), 'Y': np.random.randn(10) })
#       3
# ----> 4 df = pd.DataFrame({'1': df1, '2': df2})
#
# /home/marat/.pyenv/versions/2.7.10/envs/tesis/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     225                                  dtype=dtype, copy=copy)
#     226         elif isinstance(data, dict):
# --> 227             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     228         elif isinstance(data, ma.MaskedArray):
#     229             import numpy.ma.mrecords as mrecords
#
# /home/marat/.pyenv/versions/2.7.10/envs/tesis/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     360
#     361         return _arrays_to_mgr(arrays, data_names, index, columns,
# --> 362                               dtype=dtype)
#     363
#     364     def _init_ndarray(self, values, index, columns, dtype=None,
#
# /home/marat/.pyenv/versions/2.7.10/envs/tesis/lib/python2.7/site-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5090     # figure out the index, if necessary
#    5091     if index is None:
# -> 5092         index = extract_index(arrays)
#    5093     else:
#    5094         index = _ensure_index(index)
#
# /home/marat/.pyenv/versions/2.7.10/envs/tesis/lib/python2.7/site-packages/pandas/core/frame.pyc in extract_index(data)
#    5129
#    5130         if not indexes and not raw_lengths:
# -> 5131             raise ValueError('If using all scalar values, you must pass'
#    5132                              ' an index')
#    5133
#
# ValueError: If using all scalar values, you must pass an index
