# %% [markdown]
# # Datos de Sesión
#
# Acá vamos a armar la tabla...

# %%
# %matplotlib inline

import pylab
import config
import logging
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from tsa import entrainment, cross_correlogram
from session import SessionMapper, load_session
from tama import tama, normalize
import pandas as pd

feature = "F0_MEAN"
logger = logging.getLogger('main')
pd.set_option('display.max_columns', 100)

mapper = SessionMapper()

sessions = [load_session(i) for i in range(1,13)]

# %%
from tsa import autoregressive_prewhitening


def generate_task_series(A, B):
    l_AB, E_AB, l_BA, E_BA = entrainment(A, B, lags=range(-6, 6))
    
    return pd.Series({
        "entrainment" : E_AB,
        "best_lag" : l_AB
    })

def analyze_session(session):
    session_data = pd.DataFrame()
    
    for task in session.tasks:
        task_data = pd.Series()
        
        A, meanA = tama(task.speechA, feature)
        B, meanB = tama(task.speechB, feature)
        
        if (A.count() < config.SERIES_LENGTH_THRESHOLD) or (B.count() < config.SERIES_LENGTH_THRESHOLD):
            continue
        
        nA = normalize(A, meanA)
        nB = normalize(B, meanB)
        
        rA, rB = autoregressive_prewhitening(nA, nB)
        task_key = task.name.replace("Task", "T")
        
       
        session_data["%s_AB" % task_key] = generate_task_series(rA, rB)
        session_data["%s_BA" % task_key] = generate_task_series(rB, rA)
        continue
        
        
        session_data["%s_A_TAMA_MEAN" % task_key] = meanA
        session_data["%s_B_TAMA_MEAN" % task_key] = meanB
        session_data["%s_A_SAMPLE_MEAN" % task_key] = A.mean()
        session_data["%s_B_SAMPLE_MEAN" % task_key] = B.mean()
        
    return session_data

for session in sessions:
    session.analysis = analyze_session(session)

# %%
from IPython.display import display,HTML, display_latex

for session in sessions:
    print "\n" * 2
    print "========= %s" % session.name
    display(session.analysis.T)
# Out:
# ========= session-01
#          best_lag  entrainment
# T 10_AB         0     0.581475
# T 10_BA        -2    -0.917101
# T 12_AB        -1    -0.569677
# T 12_BA        -2     0.467112
# T 13_AB        -1     0.533701
# T 13_BA        -1    -0.602364
# ========= session-02
#          best_lag  entrainment
# T 03_AB         0     0.520696
# T 03_BA         0     0.520696
# T 04_AB        -6    -0.241060
# T 04_BA        -3    -0.249488
# T 07_AB        -1     0.743719
# T 07_BA        -3    -0.248866
# T 08_AB        -1     0.147362
# T 08_BA        -4     0.174280
# T 10_AB        -3     0.314821
# T 10_BA        -4    -0.267300
# T 11_AB        -2    -0.649042
# T 11_BA        -1    -0.235906
# T 12_AB        -3     0.744628
# T 12_BA         0    -0.186934
# T 13_AB        -2    -0.421947
# T 13_BA        -4     0.335757
# T 14_AB        -5    -0.455539
# T 14_BA        -3     0.367534
# ========= session-03
#          best_lag  entrainment
# T 01_AB         0     0.461325
# T 01_BA         0     0.461325
# T 04_AB        -1    -0.496407
# T 04_BA        -2    -0.477092
# T 08_AB         0     0.214331
# T 08_BA        -4    -0.239131
# T 10_AB        -1     0.421213
# T 10_BA        -4     0.538634
# T 12_AB        -1     0.530497
# T 12_BA        -4     0.455555
# T 13_AB        -6    -0.334702
# T 13_BA        -3     0.581576
# ========= session-04
#          best_lag  entrainment
# T 03_AB        -3    -0.491732
# T 03_BA        -1     0.186620
# T 04_AB         0     0.558016
# T 04_BA         0     0.558016
# T 05_AB        -3     0.509755
# T 05_BA        -5     0.424581
# T 07_AB        -4     0.474777
# T 07_BA        -5    -0.419765
# T 08_AB        -2    -0.260291
# T 08_BA        -3     0.378610
# T 09_AB        -2    -0.326823
# T 09_BA        -3     0.317818
# T 10_AB        -5     0.275831
# T 10_BA        -4     0.270783
# T 11_AB         0     0.542779
# T 11_BA        -1     0.573505
# T 12_AB        -1    -0.339300
# T 12_BA        -1     0.323595
# T 13_AB        -6    -0.391903
# T 13_BA        -5     0.348497
# ========= session-05
#          best_lag  entrainment
# T 03_AB        -1     0.668718
# T 03_BA        -1    -0.336566
# T 04_AB        -5    -0.568306
# T 04_BA        -4    -0.145647
# T 09_AB        -1     0.391834
# T 09_BA        -1    -0.291028
# T 11_AB        -1     0.398022
# T 11_BA        -3     0.521912
# T 13_AB        -1     0.290644
# T 13_BA        -5     0.405724
# T 14_AB        -4    -0.493111
# T 14_BA        -6     0.337201
# ========= session-06
#          best_lag  entrainment
# T 03_AB        -2     0.636468
# T 03_BA        -1    -0.541348
# T 04_AB        -5    -0.550809
# T 04_BA        -2    -0.426441
# T 05_AB        -6     0.544986
# T 05_BA        -3    -0.183199
# T 06_AB         0     0.597055
# T 06_BA         0     0.597055
# T 07_AB         0     0.846892
# T 07_BA         0     0.846892
# T 08_AB        -2    -0.375501
# T 08_BA        -4    -0.453761
# T 09_AB        -1     0.468115
# T 09_BA        -4     0.425961
# T 10_AB         0    -0.408565
# T 10_BA        -2     0.741548
# T 12_AB         0     0.537999
# T 12_BA         0     0.537999
# ========= session-07
#          best_lag  entrainment
# T 03_AB        -1     0.689481
# T 03_BA         0     0.340388
# T 04_AB         0     0.464532
# T 04_BA         0     0.464532
# T 05_AB        -6     0.270372
# T 05_BA        -3     0.254393
# T 06_AB        -1    -0.364014
# T 06_BA         0     0.212638
# T 08_AB        -1     0.455077
# T 08_BA        -3    -0.629832
# T 09_AB        -1     0.477021
# T 09_BA        -2     0.342295
# T 10_AB        -4     0.559022
# T 10_BA        -1    -0.224990
# T 11_AB         0    -0.674893
# T 11_BA         0    -0.674893
# T 12_AB         0    -0.273502
# T 12_BA         0    -0.273502
# T 14_AB        -2    -0.601743
# T 14_BA        -1     0.354144
# ========= session-08
#          best_lag  entrainment
# T 03_AB         0    -0.475691
# T 03_BA        -1     0.674365
# T 05_AB        -3    -0.407415
# T 05_BA        -4    -0.325204
# T 06_AB        -1     0.705364
# T 06_BA        -2     0.277948
# T 07_AB        -2     0.544220
# T 07_BA        -3     0.469076
# T 08_AB        -1    -0.554425
# T 08_BA         0    -0.488752
# T 10_AB        -1     0.459344
# T 10_BA        -4    -0.621277
# T 12_AB         0    -0.506939
# T 12_BA        -1    -0.522927
# T 13_AB        -1     0.707602
# T 13_BA        -3    -0.306751
# T 14_AB        -6     0.327638
# T 14_BA        -2    -0.508360
# ========= session-09
#          best_lag  entrainment
# T 01_AB         0     0.577537
# T 01_BA         0     0.577537
# T 02_AB         0     0.588267
# T 02_BA         0     0.588267
# T 04_AB        -1    -0.599913
# T 04_BA        -1     0.816473
# T 05_AB         0    -0.871287
# T 05_BA         0    -0.871287
# T 06_AB        -1     0.453906
# T 06_BA        -1    -0.247688
# T 07_AB        -3     0.420993
# T 07_BA        -1    -0.743012
# T 09_AB         0     0.618991
# T 09_BA         0     0.618991
# T 11_AB        -5    -0.465764
# T 11_BA        -2     0.347123
# T 13_AB         0    -0.478039
# T 13_BA         0    -0.478039
# T 14_AB        -1     0.658056
# T 14_BA         0     0.301022
# ========= session-10
#          best_lag  entrainment
# T 01_AB        -5     0.650052
# T 01_BA        -4    -0.360841
# T 02_AB         0     0.750570
# T 02_BA         0     0.750570
# T 03_AB        -5    -0.424622
# T 03_BA        -5    -0.319371
# T 04_AB         0    -0.260488
# T 04_BA         0    -0.260488
# T 05_AB        -6    -0.191536
# T 05_BA        -3     0.270491
# T 06_AB        -2     0.234354
# T 06_BA        -2     0.680179
# T 07_AB        -2    -0.428121
# T 07_BA        -4    -0.589946
# T 08_AB        -6     0.321845
# T 08_BA        -2    -0.436830
# T 09_AB        -4    -0.201716
# T 09_BA        -4     0.144084
# T 10_AB        -3    -0.182083
# T 10_BA        -6     0.225278
# T 11_AB        -4     0.441656
# T 11_BA        -3     0.379998
# T 12_AB        -1     0.292349
# T 12_BA        -1    -0.150605
# T 13_AB        -3     0.465059
# T 13_BA        -6     0.199316
# T 14_AB        -3     0.258466
# T 14_BA        -2     0.463486
# ========= session-11
#          best_lag  entrainment
# T 03_AB        -4    -0.359052
# T 03_BA        -1     0.779164
# T 04_AB        -4    -0.541239
# T 04_BA        -1     0.510650
# T 06_AB         0    -0.765238
# T 06_BA         0    -0.765238
# T 07_AB        -1    -0.509592
# T 07_BA         0    -0.382052
# T 09_AB         0    -0.809028
# T 09_BA         0    -0.809028
# T 10_AB         0     0.576432
# T 10_BA         0     0.576432
# T 11_AB         0     0.665501
# T 11_BA         0     0.665501
# T 13_AB        -2    -0.461427
# T 13_BA        -3    -0.394068
# T 14_AB        -1    -0.589818
# T 14_BA        -1     0.739356
# ========= session-12
#          best_lag  entrainment
# T 01_AB        -2     0.761334
# T 01_BA        -1    -0.165421
# T 04_AB        -3     0.395973
# T 04_BA        -1     0.498783
# T 06_AB         0     0.707887
# T 06_BA         0     0.707887
# T 08_AB         0    -0.365301
# T 08_BA        -3     0.440404
# T 09_AB        -5     0.445727
# T 09_BA        -2     0.724765
# T 10_AB         0    -0.546508
# T 10_BA         0    -0.546508
# T 11_AB        -2     0.837536
# T 11_BA         0    -0.549116
# T 12_AB         0     0.667727
# T 12_BA         0     0.667727
# T 13_AB        -3    -0.437852
# T 13_BA        -1     0.814708
# T 14_AB        -5    -0.570768
# T 14_BA         0    -0.356937

# %% [markdown]
# ## Solo datos de entrainment
#
# $E_{AB}$ nota el `entrainment` de A hacia B, es decir, la mejor correlación cruzada moviendo A.

# %%
import re
entrainment_data = [f for f in df.index if re.match(".*(EAB|EBA).*", f)]

df.ix[entrainment_data].T
# Out:
#       T 01_EAB T 01_EAB_LAG   T 01_EBA T 01_EBA_LAG   T 02_EAB T 02_EAB_LAG  \
# S01        NaN          NaN        NaN          NaN        NaN          NaN
# S02        NaN          NaN        NaN          NaN        NaN          NaN
# S03  0.6452112            0  0.6452112            0        NaN          NaN
# S04        NaN          NaN        NaN          NaN        NaN          NaN
# S05        NaN          NaN        NaN          NaN        NaN          NaN
# S06        NaN          NaN        NaN          NaN        NaN          NaN
# S07        NaN          NaN        NaN          NaN        NaN          NaN
# S08        NaN          NaN        NaN          NaN        NaN          NaN
# S09  0.5590609            0  0.5590609            0  0.5664827            0
# S10  0.6490383           -5 -0.3158535            4  0.7802249            0
# S11        NaN          NaN        NaN          NaN        NaN          NaN
# S12  0.8002541           -1  0.2409647            0        NaN          NaN
#
#       T 02_EBA T 02_EBA_LAG   T 03_EAB T 03_EAB_LAG   T 03_EBA T 03_EBA_LAG  \
# S01        NaN          NaN        NaN          NaN        NaN          NaN
# S02        NaN          NaN  0.5209423            0  0.5209423            0
# S03        NaN          NaN        NaN          NaN        NaN          NaN
# S04        NaN          NaN -0.4152758           -3 -0.2004618            3
# S05        NaN          NaN  0.6693733           -1 -0.3383764            1
# S06        NaN          NaN  0.7241674           -2 -0.5779458            2
# S07        NaN          NaN  0.7410031           -1  0.5467498            0
# S08        NaN          NaN -0.5052196           -1  0.6082855            1
# S09  0.5664827            0        NaN          NaN        NaN          NaN
# S10  0.7802249            0 -0.4942916           -5  -0.349487            0
# S11        NaN          NaN  0.4287889            0  0.7944253            1
# S12        NaN          NaN        NaN          NaN        NaN          NaN
#
#       T 04_EAB T 04_EAB_LAG   T 04_EBA T 04_EBA_LAG   T 05_EAB T 05_EAB_LAG  \
# S01        NaN          NaN        NaN          NaN        NaN          NaN
# S02 -0.1926071           -6 -0.4534955            3        NaN          NaN
# S03 -0.3228668           -1 -0.5792411            2        NaN          NaN
# S04  0.5486129            0  0.5486129            0  -0.497062           -2
# S05 -0.5616542           -5 -0.1064324            4        NaN          NaN
# S06 -0.5443231           -5 -0.4264055            2  0.5590077           -6
# S07  0.4016898            0 -0.4205263            3  0.3590601           -6
# S08        NaN          NaN        NaN          NaN -0.4244364           -3
# S09 -0.5552593           -1  0.8563123            1 -0.7952434            0
# S10 -0.2930295            0 -0.2930295            0 -0.2079471           -5
# S11 -0.5435333           -4  0.5226916            1        NaN          NaN
# S12  0.3434941            0  0.6205335            1        NaN          NaN
#
#       T 05_EBA T 05_EBA_LAG   T 06_EAB T 06_EAB_LAG   T 06_EBA T 06_EBA_LAG  \
# S01        NaN          NaN        NaN          NaN        NaN          NaN
# S02        NaN          NaN        NaN          NaN        NaN          NaN
# S03        NaN          NaN        NaN          NaN        NaN          NaN
# S04  0.4322803            5        NaN          NaN        NaN          NaN
# S05        NaN          NaN        NaN          NaN        NaN          NaN
# S06 -0.1962029            2  0.5861269            0  0.5861269            0
# S07  0.2889775            3 -0.3451346           -1   0.225175            0
# S08 -0.3212005            4  0.7278322           -1  0.3872976            0
# S09 -0.7952434            0    0.50998           -1 -0.2390878            1
# S10  0.2987772            3  0.3730493            0  0.5902719            2
# S11        NaN          NaN -0.8510703            0 -0.8510703            0
# S12        NaN          NaN  0.7326229            0  0.7862157            1
#
#       T 07_EAB T 07_EAB_LAG   T 07_EBA T 07_EBA_LAG   T 08_EAB T 08_EAB_LAG  \
# S01        NaN          NaN        NaN          NaN        NaN          NaN
# S02  0.7606215           -1 -0.2612376            3  0.1622925           -1
# S03        NaN          NaN        NaN          NaN  0.2783827            0
# S04  0.3849032           -4  0.3400615            3 -0.3097581           -2
# S05        NaN          NaN        NaN          NaN        NaN          NaN
# S06  0.9145809            0  0.9145809            0 -0.4008364           -2
# S07        NaN          NaN        NaN          NaN  0.5696322           -1
# S08 -0.4636115           -5  0.5153191            3 -0.5248303           -1
# S09  0.5386466           -2 -0.7021258            1        NaN          NaN
# S10  0.4491982            0  -0.706681            4  0.3118179           -6
# S11 -0.6580265           -1 -0.5562471            0        NaN          NaN
# S12        NaN          NaN        NaN          NaN -0.3940617            0
#
#       T 08_EBA T 08_EBA_LAG   T 09_EAB T 09_EAB_LAG   T 09_EBA T 09_EBA_LAG  \
# S01        NaN          NaN        NaN          NaN        NaN          NaN
# S02  0.1832954            4        NaN          NaN        NaN          NaN
# S03 -0.3697226            4        NaN          NaN        NaN          NaN
# S04  0.3492752            3 -0.3576946           -2  0.3069131            5
# S05        NaN          NaN  0.4972583           -1 -0.3711102            5
# S06  0.4322381            1   0.567774           -1  0.4875368            4
# S07 -0.6021582            3  0.5257361           -1  0.4925041            0
# S08 -0.4135254            0        NaN          NaN        NaN          NaN
# S09        NaN          NaN  0.7145477            0  0.7145477            0
# S10 -0.4309311            2 -0.2720684           -4 -0.1443471            1
# S11        NaN          NaN -0.8322783            0 -0.8322783            0
# S12  0.5307211            4 -0.6377237           -1  0.6576936            2
#
#       T 10_EAB T 10_EAB_LAG   T 10_EBA T 10_EBA_LAG   T 11_EAB T 11_EAB_LAG  \
# S01  0.5741258            0 -0.9158579            2        NaN          NaN
# S02  0.4450306           -3  -0.425455            5 -0.7143471           -2
# S03  0.3994263           -1  0.5084779            4        NaN          NaN
# S04 -0.3026926           -1 -0.2602986            0  0.5094561            0
# S05        NaN          NaN        NaN          NaN  0.4016872           -1
# S06  0.3295115           -2  0.7122943            2        NaN          NaN
# S07  0.5789686           -4 -0.2183382            1 -0.7178589            0
# S08  0.5203282            0 -0.6612728            3        NaN          NaN
# S09        NaN          NaN        NaN          NaN -0.4625317           -5
# S10 -0.2035942           -2  0.1722415            4  0.5173209           -4
# S11  0.5811163            0  0.5811163            0  0.7756626            0
# S12  -0.557824           -6 -0.5237669            0  0.8112496           -2
#
#       T 11_EBA T 11_EBA_LAG   T 12_EAB T 12_EAB_LAG   T 12_EBA T 12_EBA_LAG  \
# S01        NaN          NaN  -0.544435           -1  0.6867046            2
# S02  0.3102086            3  0.7529907           -3 -0.2092417            0
# S03        NaN          NaN -0.5042716           -4  0.4642365            4
# S04  0.5614469            1 -0.2772134           -1  0.3416544            1
# S05   0.526238            3        NaN          NaN        NaN          NaN
# S06        NaN          NaN  0.6231257           -1  0.6161451            0
# S07 -0.7178589            0 -0.2792654           -4  0.2179355            4
# S08        NaN          NaN -0.6804681            0 -0.7409111            1
# S09  0.4067125            2        NaN          NaN        NaN          NaN
# S10 -0.3575133            5  0.2942333           -1 -0.1515295            1
# S11  0.7756626            0        NaN          NaN        NaN          NaN
# S12 -0.5020162            1   0.673822            0   0.673822            0
#
#       T 13_EAB T 13_EAB_LAG   T 13_EBA T 13_EBA_LAG   T 14_EAB T 14_EAB_LAG  \
# S01  0.3586872           -1 -0.7533556            1        NaN          NaN
# S02 -0.2742769           -2 -0.2311362            5  -0.456669           -5
# S03 -0.2992181           -6  0.6375297            3        NaN          NaN
# S04 -0.4151698           -3  0.5270042            5        NaN          NaN
# S05  0.3204974           -1  0.4066265            5 -0.7043198           -4
# S06        NaN          NaN        NaN          NaN        NaN          NaN
# S07        NaN          NaN        NaN          NaN -0.6888656           -2
# S08  0.7238395           -1 -0.4092831            2  0.3631451           -6
# S09 -0.3786188            0  0.5637323            2  0.6747288           -1
# S10   0.352724           -3   0.410973            5  0.2713505            0
# S11  0.4081813            0  0.4081813            0 -0.5943177           -1
# S12 -0.4306967           -3  0.8360741            1 -0.5483857           -5
#
#       T 14_EBA T 14_EBA_LAG
# S01        NaN          NaN
# S02  0.3788083            3
# S03        NaN          NaN
# S04        NaN          NaN
# S05   0.194336            2
# S06        NaN          NaN
# S07  0.3656613            2
# S08 -0.5767825            2
# S09  0.3732744            0
# S10 -0.6256569            4
# S11  0.7341087            1
# S12 -0.3440338            0
